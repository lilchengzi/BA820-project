# %% [markdown]
# <a href="https://colab.research.google.com/github/lilchengzi/BA820-project/blob/main/BA820_Team_Project_Market%20Basket%20Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Importing libraries and loading the dataset

# %%
# !pip install opendatasets
# Out:
# Requirement already satisfied: opendatasets in /usr/local/lib/python3.10/dist-packages (0.1.22)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatasets) (4.66.2)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (from opendatasets) (1.5.16)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from opendatasets) (8.1.7)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.31.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.6)

# %%
#importing necessary libraries

import opendatasets as od
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
od.download(
    "https://www.kaggle.com/datasets/yasserh/instacart-online-grocery-basket-analysis-dataset")
# Out:
# Skipping, found downloaded files in "./instacart-online-grocery-basket-analysis-dataset" (use force=True to force download)

# %%
# loading all dataframes

aisles = pd.read_csv('/content/instacart-online-grocery-basket-analysis-dataset/aisles.csv')
dept = pd.read_csv('/content/instacart-online-grocery-basket-analysis-dataset/departments.csv')
orders_prior = pd.read_csv('/content/instacart-online-grocery-basket-analysis-dataset/order_products__prior.csv')
orders = pd.read_csv('/content/instacart-online-grocery-basket-analysis-dataset/orders.csv')
prod = pd.read_csv('/content/instacart-online-grocery-basket-analysis-dataset/products.csv')

# %%
orders_prior.shape
# Out:
# (32434489, 4)

# %% [markdown]
# Since this dataframe is too huge to work with, we will sample it to a smaller size moving forward.

# %%
orders_prior1 = orders_prior.sample(frac=0.01, random_state=42)
orders_prior1
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 29481110   3109255       34099                 16          0
# 2852353     301098       41950                  5          0
# 11194500   1181866       45066                  8          0
# 15909397   1678630        8859                  2          1
# 6101870     644090       24781                  2          0
# ...            ...         ...                ...        ...
# 13579781   1433375       34969                  5          1
# 22168330   2338221       10248                 10          0
# 4041427     426460       27676                  7          0
# 4328233     456879       38028                  2          1
# 31706271   3344107       40706                  4          1
#
# [324345 rows x 4 columns]

# %%
# joining them together on common keys

df1 = pd.merge(prod, aisles, how='inner', on='aisle_id')
df2 = df1.merge(dept, how='inner', on='department_id')
df3 = df2.merge(orders_prior1, how='inner', on='product_id')
df4 = df3.merge(orders, how='inner', on='order_id')

df4
df = df4.copy()
df
# Out:
#         product_id                                       product_name  \
# 0                1                         Chocolate Sandwich Cookies
# 1                1                         Chocolate Sandwich Cookies
# 2                1                         Chocolate Sandwich Cookies
# 3                1                         Chocolate Sandwich Cookies
# 4                1                         Chocolate Sandwich Cookies
# ...            ...                                                ...
# 324340       30365                                    Vegetable Chips
# 324341       30365                                    Vegetable Chips
# 324342       30365                                    Vegetable Chips
# 324343       48778  Fit Super A Juice, Cold Pressed, Carrot/Apple/...
# 324344       48778  Fit Super A Juice, Cold Pressed, Carrot/Apple/...
#
#         aisle_id  department_id                         aisle department  \
# 0             61             19                 cookies cakes     snacks
# 1             61             19                 cookies cakes     snacks
# 2             61             19                 cookies cakes     snacks
# 3             61             19                 cookies cakes     snacks
# 4             61             19                 cookies cakes     snacks
# ...          ...            ...                           ...        ...
# 324340        18             10  bulk dried fruits vegetables       bulk
# 324341        18             10  bulk dried fruits vegetables       bulk
# 324342        18             10  bulk dried fruits vegetables       bulk
# 324343        18             10  bulk dried fruits vegetables       bulk
# 324344        18             10  bulk dried fruits vegetables       bulk
#
#         order_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         924888                 11          1   177411    prior
# 1         268506                 13          1   157915    prior
# 2        2109664                  4          0   145504    prior
# 3        3209740                  2          1     7981    prior
# 4        1550174                  1          1    66968    prior
# ...          ...                ...        ...      ...      ...
# 324340   1954609                  7          0   130601    prior
# 324341   2323735                  1          1    90235    prior
# 324342    878186                  7          1   130467    prior
# 324343   2748395                  1          0    96923    prior
# 324344   2313474                 10          1   130115    prior
#
#         order_number  order_dow  order_hour_of_day  days_since_prior_order
# 0                 72          5                  1                     4.0
# 1                 20          1                  9                    20.0
# 2                  3          2                 14                     1.0
# 3                 24          2                 13                     6.0
# 4                 15          3                 16                    15.0
# ...              ...        ...                ...                     ...
# 324340            14          5                 13                     9.0
# 324341            30          3                 10                     1.0
# 324342             2          4                 17                     5.0
# 324343             4          4                 10                     2.0
# 324344            11          0                 20                    11.0
#
# [324345 rows x 15 columns]

# %% [markdown]
# ##Exploring the dataset

# %%
df.eval_set.unique()
# Out:
# array(['prior'], dtype=object)

# %%
df = df.drop('eval_set', axis=1)

# %% [markdown]
# Dropping the eval_set column since it holds no relevance and is merely a label for orders with only one label present.

# %%
df.isna().sum()
# Out:
# product_id                    0
# product_name                  0
# aisle_id                      0
# department_id                 0
# aisle                         0
# department                    0
# order_id                      0
# add_to_cart_order             0
# reordered                     0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    20775
# dtype: int64

# %% [markdown]
# Null values are only observed in the 'days_since_prior_order' column. We shall explore this further now.

# %%
df[df.days_since_prior_order.isnull()]
# Out:
#         product_id                                    product_name  aisle_id  \
# 15              78               Nutter Butter Cookie Bites Go-Pak        61
# 26             449                       Chips Ahoy! Chewy Cookies        61
# 43             796  Chocolate Reese's Peanut Butter Cup Creme Oreo        61
# 49            1648             Chocolate Chip 1.4 oz Packs Cookies        61
# 50           26283                                      White Corn        83
# ...            ...                                             ...       ...
# 324252        5161                                     Dried Mango        18
# 324253        5161                                     Dried Mango        18
# 324268        5161                                     Dried Mango        18
# 324298        5161                                     Dried Mango        18
# 324332       22827                      Organic Black Mission Figs        18
#
#         department_id                         aisle department  order_id  \
# 15                 19                 cookies cakes     snacks   2749907
# 26                 19                 cookies cakes     snacks   2283973
# 43                 19                 cookies cakes     snacks    542105
# 49                 19                 cookies cakes     snacks   2887816
# 50                  4              fresh vegetables    produce   2887816
# ...               ...                           ...        ...       ...
# 324252             10  bulk dried fruits vegetables       bulk   1965398
# 324253             10  bulk dried fruits vegetables       bulk    411935
# 324268             10  bulk dried fruits vegetables       bulk   1924992
# 324298             10  bulk dried fruits vegetables       bulk   2342697
# 324332             10  bulk dried fruits vegetables       bulk   1609534
#
#         add_to_cart_order  reordered  user_id  order_number  order_dow  \
# 15                     21          0    63660             1          6
# 26                     22          0   152748             1          0
# 43                      2          0   112211             1          1
# 49                     23          0   168253             1          0
# 50                     27          0   168253             1          0
# ...                   ...        ...      ...           ...        ...
# 324252                  2          0    50495             1          1
# 324253                  1          0    61591             1          4
# 324268                  4          0   101510             1          6
# 324298                 15          0   171175             1          6
# 324332                  4          0   194381             1          0
#
#         order_hour_of_day  days_since_prior_order
# 15                     17                     NaN
# 26                     12                     NaN
# 43                     17                     NaN
# 49                     16                     NaN
# 50                     16                     NaN
# ...                   ...                     ...
# 324252                  8                     NaN
# 324253                 15                     NaN
# 324268                  8                     NaN
# 324298                 13                     NaN
# 324332                 22                     NaN
#
# [20775 rows x 14 columns]

# %% [markdown]
# These null values might be suggesting that no prior purchase of the product was made by the customer. We can impute it with an arbitrary float value instead so that it is in line with the datatype of the column and holds value.

# %%
# imputing a value to null values of days_since_prior_order so that those rows can be used for meaningful analysis

df['days_since_prior_order'].fillna(9999.0, inplace=True) # here 9999 is our arbitrary number
df['days_since_prior_order'].isna().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 324345 entries, 0 to 324344
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   product_id              324345 non-null  int64
#  1   product_name            324345 non-null  object
#  2   aisle_id                324345 non-null  int64
#  3   department_id           324345 non-null  int64
#  4   aisle                   324345 non-null  object
#  5   department              324345 non-null  object
#  6   order_id                324345 non-null  int64
#  7   add_to_cart_order       324345 non-null  int64
#  8   reordered               324345 non-null  int64
#  9   user_id                 324345 non-null  int64
#  10  order_number            324345 non-null  int64
#  11  order_dow               324345 non-null  int64
#  12  order_hour_of_day       324345 non-null  int64
#  13  days_since_prior_order  324345 non-null  float64
# dtypes: float64(1), int64(10), object(3)
# memory usage: 37.1+ MB

# %% [markdown]
# The data types seem relevant to their respective columns.

# %%
df.describe()
# Out:
#           product_id       aisle_id  department_id      order_id  \
# count  324345.000000  324345.000000  324345.000000  3.243450e+05
# mean    25551.139194      71.198033       9.938035  1.710520e+06
# std     14110.454313      38.222234       6.276621  9.869484e+05
# min         1.000000       1.000000       1.000000  4.300000e+01
# 25%     13431.000000      31.000000       4.000000  8.559500e+05
# 50%     25167.000000      83.000000       9.000000  1.709853e+06
# 75%     37892.000000     107.000000      16.000000  2.561704e+06
# max     49688.000000     134.000000      21.000000  3.421081e+06
#
#        add_to_cart_order      reordered        user_id   order_number  \
# count      324345.000000  324345.000000  324345.000000  324345.000000
# mean            8.376010       0.589536  102951.981295      17.144796
# std             7.158359       0.491919   59441.408028      17.502843
# min             1.000000       0.000000       2.000000       1.000000
# 25%             3.000000       0.000000   51566.000000       5.000000
# 50%             6.000000       1.000000  102527.000000      11.000000
# 75%            11.000000       1.000000  154508.000000      24.000000
# max           110.000000       1.000000  206208.000000      99.000000
#
#            order_dow  order_hour_of_day  days_since_prior_order
# count  324345.000000      324345.000000           324345.000000
# mean        2.733216          13.428571              650.840648
# std         2.090947           4.251041             2445.515842
# min         0.000000           0.000000                0.000000
# 25%         1.000000          10.000000                5.000000
# 50%         3.000000          13.000000                8.000000
# 75%         5.000000          16.000000               18.000000
# max         6.000000          23.000000             9999.000000

# %%
df.describe(include='object')
# Out:
#        product_name         aisle department
# count        324345        324345     324345
# unique        25415           134         21
# top          Banana  fresh fruits    produce
# freq           4754         36393      94761

# %% [markdown]
# Having a look at the summary statistics gives us a clearer picture of the dataset to perform further analysis.

# %%
# converting day of the week (dow) of order from numerical to weekday name

# Define a mapping dictionary
dow_mapping = {
    0: 'Sunday',
    1: 'Monday',
    2: 'Tuesday',
    3: 'Wednesday',
    4: 'Thursday',
    5: 'Friday',
    6: 'Saturday'
}

# Use the map function to apply the mapping
df['order_dow'] = df['order_dow'].map(dow_mapping)
df
# Out:
#         product_id                                       product_name  \
# 0                1                         Chocolate Sandwich Cookies
# 1                1                         Chocolate Sandwich Cookies
# 2                1                         Chocolate Sandwich Cookies
# 3                1                         Chocolate Sandwich Cookies
# 4                1                         Chocolate Sandwich Cookies
# ...            ...                                                ...
# 324340       30365                                    Vegetable Chips
# 324341       30365                                    Vegetable Chips
# 324342       30365                                    Vegetable Chips
# 324343       48778  Fit Super A Juice, Cold Pressed, Carrot/Apple/...
# 324344       48778  Fit Super A Juice, Cold Pressed, Carrot/Apple/...
#
#         aisle_id  department_id                         aisle department  \
# 0             61             19                 cookies cakes     snacks
# 1             61             19                 cookies cakes     snacks
# 2             61             19                 cookies cakes     snacks
# 3             61             19                 cookies cakes     snacks
# 4             61             19                 cookies cakes     snacks
# ...          ...            ...                           ...        ...
# 324340        18             10  bulk dried fruits vegetables       bulk
# 324341        18             10  bulk dried fruits vegetables       bulk
# 324342        18             10  bulk dried fruits vegetables       bulk
# 324343        18             10  bulk dried fruits vegetables       bulk
# 324344        18             10  bulk dried fruits vegetables       bulk
#
#         order_id  add_to_cart_order  reordered  user_id  order_number  \
# 0         924888                 11          1   177411            72
# 1         268506                 13          1   157915            20
# 2        2109664                  4          0   145504             3
# 3        3209740                  2          1     7981            24
# 4        1550174                  1          1    66968            15
# ...          ...                ...        ...      ...           ...
# 324340   1954609                  7          0   130601            14
# 324341   2323735                  1          1    90235            30
# 324342    878186                  7          1   130467             2
# 324343   2748395                  1          0    96923             4
# 324344   2313474                 10          1   130115            11
#
#         order_dow  order_hour_of_day  days_since_prior_order
# 0          Friday                  1                     4.0
# 1          Monday                  9                    20.0
# 2         Tuesday                 14                     1.0
# 3         Tuesday                 13                     6.0
# 4       Wednesday                 16                    15.0
# ...           ...                ...                     ...
# 324340     Friday                 13                     9.0
# 324341  Wednesday                 10                     1.0
# 324342   Thursday                 17                     5.0
# 324343   Thursday                 10                     2.0
# 324344     Sunday                 20                    11.0
#
# [324345 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 324345 entries, 0 to 324344
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   product_id              324345 non-null  int64
#  1   product_name            324345 non-null  object
#  2   aisle_id                324345 non-null  int64
#  3   department_id           324345 non-null  int64
#  4   aisle                   324345 non-null  object
#  5   department              324345 non-null  object
#  6   order_id                324345 non-null  int64
#  7   add_to_cart_order       324345 non-null  int64
#  8   reordered               324345 non-null  int64
#  9   user_id                 324345 non-null  int64
#  10  order_number            324345 non-null  int64
#  11  order_dow               324345 non-null  object
#  12  order_hour_of_day       324345 non-null  int64
#  13  days_since_prior_order  324345 non-null  float64
# dtypes: float64(1), int64(9), object(4)
# memory usage: 37.1+ MB

# %% [markdown]
# ##EDA

# %% [markdown]
# Performing various exploratory data analyses to get to know the data better.

# %%
# number of unique products in each aisle

df.groupby('aisle').product_id.nunique()
# Out:
# aisle
# air fresheners candles           113
# asian foods                      320
# baby accessories                  12
# baby bath body care               50
# baby food formula                441
#                                 ...
# trash bags liners                 65
# vitamins supplements             244
# water seltzer sparkling water    239
# white wines                       63
# yogurt                           741
# Name: product_id, Length: 134, dtype: int64

# %%
# number of unique products in each departments

df.groupby('department').product_id.nunique()
# Out:
# department
# alcohol             398
# babies              586
# bakery              973
# beverages          2425
# breakfast           682
# bulk                 28
# canned goods       1158
# dairy eggs         2377
# deli                809
# dry goods pasta    1030
# frozen             2413
# household          1398
# international       538
# meat seafood        539
# missing             252
# other               166
# pantry             2570
# personal care      1984
# pets                406
# produce            1227
# snacks             3456
# Name: product_id, dtype: int64

# %%
# order id with the biggest order

max_order = df.add_to_cart_order.max()
df[df.add_to_cart_order==max_order].loc[:,['order_id', 'user_id']]
# Out:
#        order_id  user_id
# 29349   3308010   129928

# %%
# top customers based on purchase quantity

top_cust = df.groupby('user_id').order_id.count().reset_index()
top_cust.sort_values('order_id', ascending = False).head(10)
# Out:
#         user_id  order_id
# 115796   201268        44
# 79220    137629        43
# 80839    140440        37
# 62530    108187        37
# 104955   182401        36
# 41684     72136        35
# 19369     33731        33
# 101577   176478        32
# 94457    164055        32
# 58010    100330        31

# %% [markdown]
# ###Further Analysis

# %%
# most popular products based on purchases

top_prod = df.product_name.value_counts().reset_index()
top_prod = top_prod.sort_values('product_name', ascending = False).head(10)

sns.barplot(data=top_prod, x='index', y='product_name')
plt.xlabel('Product Name')
plt.ylabel('Quantity Sold')
plt.title('Most populatr products')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# As seen in the visualization above, Bananas are the the most popular products sold at Instacart. It can also be seen that most of these top 10 products are organic products.

# %%
# what day do most orders take place

dow = df.groupby('order_dow').order_id.nunique().reset_index()

sns.barplot(data=dow, x='order_dow', y='order_id');
plt.title('Orders based on day of week', fontsize = 14)
plt.xlabel('Day of Week')
plt.ylabel('No of Orders')
plt.show()

# %% [markdown]
# It can be observed from the illustration above that Sunday sees the maximum amount of orders, which could possibly be due to people shopping for groceries in the weekend.

# %%
df
# Out:
#         product_id                                       product_name  \
# 0                1                         Chocolate Sandwich Cookies
# 1                1                         Chocolate Sandwich Cookies
# 2                1                         Chocolate Sandwich Cookies
# 3                1                         Chocolate Sandwich Cookies
# 4                1                         Chocolate Sandwich Cookies
# ...            ...                                                ...
# 324340       30365                                    Vegetable Chips
# 324341       30365                                    Vegetable Chips
# 324342       30365                                    Vegetable Chips
# 324343       48778  Fit Super A Juice, Cold Pressed, Carrot/Apple/...
# 324344       48778  Fit Super A Juice, Cold Pressed, Carrot/Apple/...
#
#         aisle_id  department_id                         aisle department  \
# 0             61             19                 cookies cakes     snacks
# 1             61             19                 cookies cakes     snacks
# 2             61             19                 cookies cakes     snacks
# 3             61             19                 cookies cakes     snacks
# 4             61             19                 cookies cakes     snacks
# ...          ...            ...                           ...        ...
# 324340        18             10  bulk dried fruits vegetables       bulk
# 324341        18             10  bulk dried fruits vegetables       bulk
# 324342        18             10  bulk dried fruits vegetables       bulk
# 324343        18             10  bulk dried fruits vegetables       bulk
# 324344        18             10  bulk dried fruits vegetables       bulk
#
#         order_id  add_to_cart_order  reordered  user_id  order_number  \
# 0         924888                 11          1   177411            72
# 1         268506                 13          1   157915            20
# 2        2109664                  4          0   145504             3
# 3        3209740                  2          1     7981            24
# 4        1550174                  1          1    66968            15
# ...          ...                ...        ...      ...           ...
# 324340   1954609                  7          0   130601            14
# 324341   2323735                  1          1    90235            30
# 324342    878186                  7          1   130467             2
# 324343   2748395                  1          0    96923             4
# 324344   2313474                 10          1   130115            11
#
#         order_dow  order_hour_of_day  days_since_prior_order
# 0          Friday                  1                     4.0
# 1          Monday                  9                    20.0
# 2         Tuesday                 14                     1.0
# 3         Tuesday                 13                     6.0
# 4       Wednesday                 16                    15.0
# ...           ...                ...                     ...
# 324340     Friday                 13                     9.0
# 324341  Wednesday                 10                     1.0
# 324342   Thursday                 17                     5.0
# 324343   Thursday                 10                     2.0
# 324344     Sunday                 20                    11.0
#
# [324345 rows x 14 columns]

# %% [markdown]
# ##Market Basket Analysis

# %% [markdown]
# ###Data Preparation

# %%
# importing necessary libraries

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
mba = orders_prior[['order_id', 'product_id']].merge(prod[['product_id', 'product_name']], how='inner', on='product_id')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_mba1 = mba.groupby('order_id')['product_name'].apply(','.join).reset_index()
df_mba1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          order_id                                       product_name
# 0               2  Organic Egg Whites,Michigan Organic Kale,Garli...
# 1               3  Total 2% with Strawberry Lowfat Greek Strained...
# 2               4  Plain Pre-Sliced Bagels,Honey/Lemon Cough Drop...
# 3               5  Bag of Organic Bananas,Just Crisp, Parmesan,Fr...
# 4               6  Cleanse,Dryer Sheets Geranium Scent,Clean Day ...
# ...           ...                                                ...
# 3214869   3421079                                      Moisture Soap
# 3214870   3421080  Organic Cilantro,Organic Whole Milk,Organic To...
# 3214871   3421081  Lime Sparkling Water,Classic Wheat Bread,Dijon...
# 3214872   3421082  Raspberries,Strawberries,Toasted Coconut Chips...
# 3214873   3421083  Banana,Organic Mixed Berry Yogurt & Fruit Snac...
#
# [3214874 rows x 2 columns]

# %%
df_mba1 = df_mba1.sample(frac=0.01, random_state=42)
df_mba1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          order_id                                       product_name
# 1454590   1548381  Unsweetened Chocolate Almond Breeze Almond Mil...
# 1456155   1550066  Cherubs Heavenly Salad Tomatoes,Organic Reduce...
# 599356     638197  Carrots,Organic Baby Spinach,Yellow Onions,Org...
# 2969472   3160070  Sea Salt Pita Chips,Original Hummus,Organic Ba...
# 2442544   2599408  Canned Aranciata Orange,Oats & Honey Gluten Fr...
# ...           ...                                                ...
# 943039    1003981                                       Draught Beer
# 1359263   1446947  Unsweetened Almondmilk,Organic Raspberries,Org...
# 3088614   3286731  Smartwater Electrolyte Enhanced Water,Pinot No...
# 509730     542712  Organic Strawberries,Water,Pasta Joy Ready Org...
# 1576367   1678058  Meyer Lemon,Organic Bread with 21 Whole Grains...
#
# [32149 rows x 2 columns]

# %%
# data preparation
data_column = df_mba1.loc[:, 'product_name']
data = list(data_column.apply(lambda x: x.split(',')))
data
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['Unsweetened Chocolate Almond Breeze Almond Milk',
#   'Spring Water',
#   'Just Green Unsweetened Tea',
#   'Cream Top Smooth & Creamy Vanilla Yogurt',
#   'Cream Top Peach on the Bottom Yogurt',
#   'Broth Free Range Chicken Organic'],
#  ['Cherubs Heavenly Salad Tomatoes',
#   'Organic Reduced Fat Milk',
#   'Organic Peeled Whole Baby Carrots',
#   'Baby Seedless Cucumbers',
#   'Large Grapefruit',
#   'Organic Italian Salad',
#   'Whipped Cream Cheese',
#   'Dha Omega 3 Reduced Fat 2% Milk',
#   'Organic Black Mission Figs',
#   'Apple Apricot Sauce',
#   'Organic Turkey Hot Dogs',
#   'Chocolate Crepes',
#   'Lowfat 2% Milkfat Russian Yogurt'],
#  ['Carrots',
#   'Organic Baby Spinach',
#   'Yellow Onions',
#   'Organic Heavy Whipping Cream',
#   'Gluten Free Mushroom Risotto Bowl',
#   'Organic Fresh Basil',
#   'Shredded Parmesan',
#   'Marinara Sauce',
#   'Russet Potato',
#   'Shredded Mozzarella',
#   'Organic Italian Parsley Bunch',
#   'Premium Pure Cane Granulated Sugar',
#   'Half & Half',
#   'Broccoli & Cheddar Bake Meal Bowl',
#   'Unrefined Virgin Coconut Oil',
#   'Small Macintosh Apple',
#   'Goat Cheese Log',
#   'Vitamin D Milk',
#   'Total 2% All Natural Low Fat 2% Milkfat Greek Strained Yogurt',
#   'Gluten and Dairy Free Rice Macaroni and Cheeze',
#   'Gluten Free White Bread',
#   'Pasta Joy Ready Brown Rice Pasta Lasagne'],
#  ['Sea Salt Pita Chips',
#   'Original Hummus',
#   'Organic Baby Rainbow Carrots',
#   'Aged White Cheddar Popcorn',
#   'Mandarin Oranges',
#   'Tomato Kumato',
#   'Organic Baby Romaine Lettuce',
#   'Dark Chocolate Pretzel Snack'],
#  ['Canned Aranciata Orange',
#   'Oats & Honey Gluten Free Granola',
#   'All Natural Apricot Sparkling Water',
#   'Curate Cherry Lime Sparkling Water',
#   'Honey Wheat Braided Twists',
#   'Real Vegetable Chips Mediterranean Herbs & A Hint Of Lemon',
#   'Lady Grey Tea',
#   'NUT-rition Protein Mix Honey Nut',
#   'Fun Size Peanut Chocolate Candies'],
#  ['Bag of Organic Bananas',
#   'Sparkling Natural Mineral Water',
#   'Earl Grey Tea Bags',
#   'Sparkling Lemon Water',
#   'Sriracha Hot Chili Sauce',
#   'Lite Balsamic Dressing',
#   "Naturе's Calorie-Free Sweetener",
#   'Dinner Plates',
#   'Refreshers Strawberry Lemonade Sparkling Green Coffee Energy Drink'],
#  ['Reddiegg Egg Product',
#   'Natural Detergent 2X Ultra With Coconut Oil Based Fabric Softener Cleaner',
#   'Diced Red Onion',
#   'Diced Bell Pepper'],
#  ['Fruit & Nutty Almonds Raisins Cranberries Pecans Granola',
#   'Asparagus',
#   'Organic Gala Apples',
#   'Red Peppers',
#   'Oven Roasted Turkey',
#   'Original Hummus',
#   'Organic Reduced Fat 2% Milk',
#   'Trilogy Kombucha Drink',
#   'Plain Bagels',
#   'Hearty Nine Grain Bread',
#   'Organic Gluten Free Non-Dairy Beans & Rice Burrito',
#   'Chicken Breast Tenders Breaded',
#   'Guava Goddess Organic Kambucha',
#   'Yogurt',
#   ' Organic',
#   ' Lowfat',
#   ' Strawberry',
#   'Light in Sodium Black Bean Vegetable Enchilada Entree'],
#  ['Organic Fat Free Milk',
#   'Organic Cucumber',
#   'Sour Cream & Onion Potato Chips'],
#  ['Organic Bread with 21 Whole Grains',
#   'Banana',
#   'Garlic Hummus',
#   'Original Hummus',
#   'Thin & Light Tortilla Chips',
#   'Crunchy Peanut Butter',
#   'Half & Half',
#   'Milk',
#   ' Reduced Fat',
#   ' 2% Milkfat',
#   'Sweet Potato Tortilla Chips',
#   'Real Guacamole'],
#  ['Organic Grape Tomatoes', 'Grade A Large White Eggs', 'Ranch Dressing'],
#  ['Sparkling Water'],
#  ['Sparkling Natural Mineral Water',
#   'Organic Gala Apples',
#   'Organic Sunday Bacon',
#   'Organic Acorn Squash',
#   'Organic Small Bunch Celery',
#   'Super Spinach! Baby Spinach',
#   ' Baby Bok Choy',
#   ' Sweet Baby Kale',
#   'Organic Broccoli Crown',
#   'Organic Sliced Crimini Mushrooms'],
#  ['Cereal',
#   'Sparkling Mineral Water',
#   'Original Hot Sauce',
#   'Lemon Sparkling Water',
#   'Grapefruit Sparkling Water',
#   'Natural Lemon Flavored Sparkling Water',
#   'Hot Sauce',
#   'Sourdough Deli Bread',
#   'Natural with Sport Cap Alpine Spring Water'],
#  ['Organic Half & Half',
#   'Shredded Mexican Blend Cheese',
#   'Best Cinnamon Bread',
#   'XL Pick-A-Size Paper Towel Rolls'],
#  ['Extra Virgin Olive Oil',
#   'Banana',
#   'Green Bell Pepper',
#   'Cucumber Kirby',
#   'Roma Tomato',
#   'Organic Red Chard Greens',
#   'Black Beans',
#   'Organic Basil',
#   'Small Hass Avocado',
#   'Sweet Potato Yam',
#   'Organic Raw Kombucha Gingerade',
#   'Large Burrito Flour Tortillas',
#   'Organic Yellow Squash',
#   'Organic Green Leaf Lettuce',
#   'Traditional Favorites Tomato & Basil Pasta Sauce',
#   'Traditional Plain Greek Yogurt',
#   'Green Curry Paste',
#   'Slices Cheddar Cheese',
#   'Pure Coconut Milk',
#   'Vegetarian Refried Beans',
#   'Whole Grain Quinoa',
#   'Cut & Peeled Baby Carrots',
#   '50/50 Spring Mix & Baby Spinach',
#   'Yellow Corn Extra Thin Tortillas',
#   'Cauliflower Head',
#   'Extra Firm Tofu',
#   'Beer Brats Sausage'],
#  ['Baby Cut Carrots', 'Drinking Water'],
#  ['Bag of Organic Bananas',
#   'Organic Strawberries',
#   'Sparkling Water Grapefruit',
#   'Organic Stage 4 Spinach Mango & Pear Baby Food',
#   'Yo Baby Organic Whole Milk Banana Mango Yogurt',
#   'YoKids Squeezers Organic Low-Fat Yogurt',
#   ' Strawberry',
#   'Organic Gala Apples',
#   'Baby Food Stage 2 Blueberry Pear & Purple Carrot',
#   'Wild Berry Smoothie',
#   'Sparkling Water Berry',
#   'Organic Mixed Berry Yogurt & Fruit Snack',
#   'Organic Carrots & Ranch Dip',
#   'Whole Grain Rice Cereal',
#   'Organic Strawberry Yogurt & Fruit Snack',
#   'Kale & Spinach Superfood Puffs',
#   'Organic Homestyle Mini Waffles',
#   'Broccoli',
#   ' Kale & Cheddar Cheese Organic Veggie Snack',
#   'Real Cheddar Baked Cheese Puffs',
#   'Corn Puffs with Aged White Cheddar (Lunch Packs)'],
#  ['Vanilla Almond Breeze Almond Milk',
#   'Boneless Skinless Chicken Breast',
#   'Natural Artisan Water',
#   'Disinfecting Wet Wipes - Lemongrass Citrus',
#   'Sustainably Soft Bath Tissue',
#   'Organic Raw Kombucha Gingerade',
#   'Synergy Organic & Raw Cosmic Cranberry',
#   'Organic Cinnamon Harvest Cereal',
#   'Organic Raw Multigreen Kobmbucha',
#   'Heart to Heart Honey Toasted Oat Cereal',
#   'Yerbamate Lemon Energy Shot',
#   'Lean & Fit Chicken Apple Sausage Egg White & Cheddar on Multi Grain Flatbread Breakfast Sandwich',
#   'Daily Shower Cleaner Ylang Ylang'],
#  ['Jalapeno Peppers',
#   'Asparation/Broccolini/Baby Broccoli',
#   'Roma Tomato',
#   'Red Onion',
#   'Shredded Parmesan Cheese',
#   'Blue Chips Corn Tortilla Chips'],
#  ['Organic Spring Mix Salad',
#   'Mini Chocolate Chunk Cookies',
#   'Ginger Snap Cookies',
#   'Chocolate Chip Cookie',
#   'Chocolate Fudge High Protein Bars'],
#  ['Bag of Organic Bananas',
#   'Organic Garlic',
#   'Organic Garbanzo Beans',
#   'Organic Red Lentils',
#   'Organic Bagged Valencia Oranges'],
#  ['Banana',
#   'Feta Cheese Crumbles',
#   'Organic Yams',
#   'Shredded Parmesan',
#   'Organic Reduced Fat 2% Milk',
#   'Honey Nut Cheerios',
#   'Total 2% Lowfat Greek Strained Yogurt With Blueberry',
#   'Organic Dark Chocolate Peanut Butter Cups',
#   'YoBaby Blueberry Apple Yogurt',
#   'Ground Buffalo',
#   'Taco Seasoning',
#   'Organic Cinnamon Apple Chips',
#   "Sesame Street Organic Original Cruchin' Cracker",
#   'Organic Pineapple',
#   ' Apple & Pea Freeze Dried Snacks'],
#  ['Bag of Organic Bananas',
#   'XL Emerald White Seedless Grapes',
#   'Asparagus Spears',
#   'Mandarin Oranges',
#   'Freshly Squeezed Orange Juice'],
#  ['Clementines',
#   'Gala Apples',
#   'Green Seedless Grapes',
#   'Peaches',
#   'Bartlett Pears'],
#  ['Organic Strawberries',
#   'Sparkling Water Grapefruit',
#   'Icelandic Style Skyr Blueberry Non-fat Yogurt',
#   'Peach Pear Flavored Sparkling Water',
#   'Whole Almonds',
#   '100% Raw Coconut Water',
#   'Bartlett Pears',
#   'Tangerine',
#   'Vanilla 0% Milkfat Yogurt',
#   'Non Fat Acai & Mixed Berries Yogurt',
#   'Non Fat Raspberry Yogurt',
#   'Yogurt Covered Pretzels',
#   '7 Sprouted Grains Bread',
#   'Flourless  Sprouted Whole Grain 7-Sprouted Grains English Muffins',
#   'Shelled Pistachios',
#   'Sliced Soppressata Salame'],
#  ['Organic Half & Half',
#   'Organic Lemon',
#   'Organic Whole Kernel Sweet Corn No Salt Added',
#   'Organic Butternut Squash',
#   'White Peach',
#   'Organic Apple Juice Boxes',
#   'Ice Cream Chocolate Peanut Butter Cup'],
#  ['Sparkling Natural Mineral Water', 'Spring Water', 'Whole Hearts of Palm'],
#  ['Banana',
#   'Yellow Bell Pepper',
#   'Classic Macaroni & Beef in tomato sauce. Classic Macaroni & Beef',
#   'Sharp Cheddar',
#   'Light Italian Dressing',
#   'Comfort Chicken Marsala',
#   'Four Cheese Cannelloni with ricotta',
#   ' mozzarella',
#   ' Parmesan & Romano cheese. Four Cheese Cannelloni',
#   'Plain Baked Pita Chips',
#   'Marketplace Ricotta Cheese and Spinach Ravioli'],
#  ['Chicken & Apple Breakfast Sausage',
#   'Pecan Nut & Rice Cracker Snacks',
#   'Triple Creme Goat Brie',
#   'All Natural Sea Fresh Antiplaque & Strengthening Toothpaste Deep Sea Spearmint',
#   'Chocolate Brownie'],
#  ['Organic Raw Kombucha Gingerade',
#   'Cold Brew Coffee Nitro Can',
#   'Lightly Salted Toasted Coconut Chips',
#   '100% Raw Coconut Water With Fair Trade Coffee'],
#  ['Mango Sparkling Water',
#   'Curate Cherry Lime Sparkling Water',
#   'Pineapple Strawberry Sparkling Water'],
#  ['Sparkling Mineral Water', 'April Fresh Liquid Fabric Softener'],
#  ['Bag of Organic Bananas',
#   'Sparkling Water Grapefruit',
#   'Large Lemon',
#   'Strawberries',
#   'Organic Acai Berry Smoothie Packs',
#   'Small Hass Avocado',
#   'Sparkling Lemon Water',
#   'ALMONDBREEZE UNSWEETENED',
#   'Organic Creamy Peanut Butter',
#   'Toffee & Sea Salt Milk Chocolate Bar',
#   'Mediterranean Thin Crust Pizza'],
#  ['Organic  Whole Milk',
#   'Brown & Serve Original Breakfast Sausage Links',
#   'Crispy Crunchy Chickpeas for Snacking & Topping Sea Salt Lightly Dusted With Coarse Salt',
#   'Chocolate Chip Cookies Without Nuts'],
#  ['Bag of Organic Bananas',
#   'Organic Hass Avocado',
#   'French Baguettes',
#   ' Take & Bake',
#   ' Twin Pack',
#   'Sea Salt Made With Organic Grain Rice Chips',
#   'Uncured Genoa Salami',
#   'Organic Lemon',
#   'Tomato Sauce',
#   'Organic Sunday Bacon',
#   'Organic Strawberry Smoothie',
#   'Wild Berry Smoothie',
#   'Cheese Pizza Snacks',
#   'Super Spinach! Baby Spinach',
#   ' Baby Bok Choy',
#   ' Sweet Baby Kale',
#   'Mild Salsa',
#   'Shredded Mild Cheddar Cheese',
#   'Organic Sticks Low Moisture Part Skim Mozzarella String Cheese',
#   'Organic Mango',
#   'Organic Summer Strawberry Bunny Fruit Snacks',
#   'Pesto Tortellini  Bowls',
#   'Pita Chips Simply Naked',
#   'Turkey Pot Pie',
#   'Mint Chocolate Chip',
#   'Vanilla Pure Almond Milk',
#   'Original Sauce',
#   'Spinach Pizza Snacks',
#   'Organic Hibiscus Berry Sparkling Probiotic Drink',
#   'Organic Mini Sandwich Crackers Cheddar Cheese',
#   'Honey Turkey Breast',
#   'Multigrain Oat Bread',
#   'Lightly Sweet Popcorn',
#   'One Bun Multigrain Whole Grain Pita',
#   'Pesto Sauce',
#   'Small Compostable Waste Bag',
#   'Fresh Ciliegine Mozzarella Cheese',
#   'Sparkling Probiotic Drink Coconut',
#   'Vegetarian Refried Beans',
#   "Lowfat Strawberries 'n Cream Kefir",
#   'Organic Tulsi Turmeric Ginger Stress-Relieving & Harmonizing Caffeine Free Herbal Supplement',
#   'Nacho Cheese & Bean Snacks',
#   'Organic White Pita Bread',
#   'Raw Probiotics Women probiotic 85 Billion 32 Strains capsules',
#   'Sparkling Tangerine Probiotic Drink',
#   'Organic Smooth Move Peppermint Tea for Occasional Constipation',
#   'Organic Vanilla Nonfat Yogurt',
#   'Garlic & Wine Sopressata Salami',
#   'RAW Probiotics Men',
#   'Crunchy Sunflower Seed Bites Salt & Pepper',
#   'Wild Rice',
#   'Ginger Peach Green Tea',
#   'Sweet Tangerine Positive Energy Tea',
#   'Cilantro Chili'],
#  ['Tennessee Whiskey', 'Raspberry Peach Cordials'],
#  ['Organic Hass Avocado',
#   'Original Semisoft Cheese',
#   'Organic Bartlett Pear',
#   'Lime Sparkling Water',
#   'Natural Artisan Water',
#   'Original No Pulp 100% Florida Orange Juice',
#   'Whipped Cream Cheese',
#   'Chicken Breast Tenders Breaded',
#   'Egg Challah Rolls',
#   'Dark Chocolate Cinnamon Pecan Bar'],
#  ['Organic Raspberries',
#   'Organic Hass Avocado',
#   'Sparkling Water Grapefruit',
#   'Organic Whole Strawberries',
#   'Organic Gala Apples',
#   'Organic Lemon',
#   'Organic Large Extra Fancy Fuji Apple',
#   'Lime Sparkling Water',
#   'Organic Nectarine',
#   'Organic Small Bunch Celery',
#   'Organic Italian Parsley Bunch',
#   'Parchment Baking Paper',
#   'Peach Pear Flavored Sparkling Water',
#   'Organic Reduced Fat 2% Milk',
#   'Sparkling Lemon Water',
#   'Ground Turkey Breast',
#   'Organic Frozen Mango Chunks',
#   'Aged White Cheddar Baked Rice & Corn Puffs Gluten Free Lunch Packs',
#   'Organic Broccoli Crown',
#   'Organic Plain Whole Milk Yogurt',
#   'Mache Rosettes French Salad Mix',
#   'Lowfat Key Lime Yogurt',
#   'Organic Shredded Carrots',
#   'Organic Unsweetened Creamy Cashewmilk',
#   'Paper Snack & Sandwich Bags',
#   ' 100% Unbleached'],
#  ['Icelandic Style Skyr Blueberry Non-fat Yogurt',
#   'Vanilla Skyr Nonfat Yogurt',
#   'Non-Fat Vanilla Yogurt',
#   'ALMONDBREEZE UNSWEETENED',
#   'Vanilla 0% Milkfat Yogurt',
#   'Yogurt',
#   ' Strained Low-Fat',
#   ' Coconut',
#   'Mixed Berries Whole Milk Icelandic Style Skyr Yogurt',
#   'Non Fat Raspberry Yogurt',
#   'Potato Puffs with Roasted Garlic and Cracked Black Pepper'],
#  ['Organic Red Radish',
#   ' Bunch',
#   'Organic Black Beans',
#   'Cherubs Heavenly Salad Tomatoes',
#   'Organic Reduced Fat Milk',
#   'Sparkling Lemon Water',
#   'Gluten Free Whole Grain Bread',
#   'Wide Egg Noodles',
#   'Roasted Garlic Pasta Sauce',
#   'Wheat Hamburger Buns'],
#  ['Marinara Sauce', 'Organic Turkey Breast'],
#  ['Banana',
#   'Organic Red Onion',
#   'Large Lemon',
#   'Cucumber Kirby',
#   'Organic Fuji Apple',
#   'Organic Bartlett Pear',
#   'Limes',
#   'Jalapeno Peppers',
#   'Organic Kiwi',
#   'Bunched Cilantro',
#   'Organic Rainbow Chard Vegetable',
#   'Organic Greek Lowfat Yogurt With Blueberries',
#   'Organic Mexican Blend Finely Shredded Cheese',
#   'Country Stand Juice',
#   ' Medium Pulp'],
#  ['Organic Baby Kale',
#   'Organic Yellow Onion',
#   'Organic Grape Tomatoes',
#   'Organic Basil',
#   'Organic Greek Lowfat Yogurt With Blueberries',
#   'Gluten Free Brown Rice Penne Rigate Pasta'],
#  ['Organic Strawberries',
#   '34% Cacao Milk Chocolate Bar',
#   'Organic 1% Low Fat Milk',
#   'Uncured Genoa Salami',
#   'Large Alfresco Eggs',
#   'Organic Whole Wheat Bread',
#   'Dha Omega 3 Vitamin D Milk',
#   'Organic Grass-Fed Classic Mild Cheddar Macaroni & Cheese',
#   'Baked Aged White Cheddar Rice and Corn Puffs',
#   'Organic Hothouse Cucumbers',
#   'Himalania Fine Pink Salt',
#   'Popcorn Popping Kernels',
#   'Rice and Corn Puffs',
#   ' Baked',
#   ' Veggie',
#   'Organic Oil Canola',
#   'Organic Mayonnaise with Olive Oil',
#   'Blueberry Scones',
#   'Kiwi Spinach Peas & Green Apple',
#   'Frozen Goo-Berry Pie Kefir',
#   'Organic Stage 2 Veggie & Protein Puree Broccoli Red Lentil Oat',
#   "Sesame Street Friends Cookie Monster's Orange Tangerine Juice"],
#  ['Organic Hass Avocado',
#   'Organic Sour Cream',
#   'Cultured Low Fat Buttermilk',
#   'Organic Grade A Free Range Large Brown Eggs',
#   'Salted Sweet Cream Butter',
#   'Organic  Whole Milk',
#   'Polenta',
#   ' Organic',
#   ' Traditional Italian',
#   'Mixed Berries',
#   'Organic Fillo Dough',
#   'Honey Grahams Graham Style Crackers',
#   'Dill Weed',
#   'Burrata alla Panna'],
#  ['Cream Cheese',
#   'Organic Large Extra Fancy Fuji Apple',
#   'Whole Milk',
#   'Kids Sensible Foods Broccoli Littles',
#   'Sharp Cheddar Cheese'],
#  ['Organic Gunpowder Green Tea',
#   'Moroccan Mint Herbal Tea',
#   'Organic Aged Earl Grey Tea',
#   'Rooibos Chai Herbal Tea Bags',
#   'Organic Honeybush Tea',
#   ' Caffeine Free',
#   'Organic Rooibos Tea',
#   'Toasted Rice Green Tea Bags',
#   'Golden Chai Black Tea',
#   'Chocolate Pu Erh Tea 16 ct',
#   'Organic Chamomile Lemon Tea',
#   "Emperor's Pu-Erh Tea",
#   'Organic White Rose White Tea',
#   'Tea',
#   ' Organic',
#   ' Green Rooibos',
#   'Mate Lemon Organic Tea'],
#  ['Organic Diced Tomatoes',
#   'Seven Grain Crispy Tenders',
#   'Kale Greens',
#   'Organic Small Bunch Celery',
#   'Dairy Free Mozarella Style Shreds',
#   'Organic Yukon Gold Potato',
#   'Vegetarian Chili Seasoning',
#   'French Vanilla Soy Creamer',
#   'Vanilla Pure Almond Milk',
#   'Mandarin Oranges',
#   'Corn Starch',
#   'Maple Almond Butter',
#   'Italian Seitan',
#   'Spicy Chili Seasoning',
#   '1 Liter',
#   'Egg Replacer',
#   'Refined Canola Oil',
#   'Ghee Vanilla Bean'],
#  ['Original Semisoft Cheese',
#   'Organic Roast Beef',
#   'Whole Wheat Bread',
#   'Premium Ice Cubes'],
#  ['Organic Baby Spinach Salad',
#   'Organic Grape Tomatoes',
#   'Sea Salt & Vinegar Potato Chips',
#   'Sustainably Soft Bath Tissue',
#   'Grape White/Green Seedless',
#   'Medium Salsa',
#   'Thin Spaghetti Pasta',
#   "Bove's Vodka Pasta Sauce"],
#  ['Whole Milk',
#   'Apple Juice',
#   'Milk Chocolate Candy Bars',
#   '100% Grated Parmesan Cheese',
#   'Fun Size Crunch Candy Bars',
#   'Clover Premium Honey',
#   'Chunk Light in Water Tuna',
#   'Oikos Greek Vanilla Yogurt',
#   'Garlic Salt',
#   'Jam',
#   ' Strawberry'],
#  ['Banana',
#   'French Roast Ground Coffee',
#   'Milk',
#   ' Organic',
#   ' Vitamin D',
#   'Organic Whole Milk French Vanilla Yogurt'],
#  ['Raspberries',
#   'Organic Blueberries',
#   'Blackberries',
#   'Hass Avocados',
#   'Kiwi'],
#  ['Michigan Organic Kale',
#   'Cage Free Brown Eggs-Large',
#   ' Grade A',
#   'Organic Small Bunch Celery',
#   'Radish',
#   'Celery Hearts',
#   'Organic Baby Romaine Lettuce',
#   'Persian (Armenian) Cucumber',
#   'Ready Rice Roasted Chicken Flavored',
#   'Glacier Freeze',
#   'Vanilla Almond Coconut Almond Breeze',
#   'Cran-Cherry Juice Drink'],
#  ['Organic Beef Uncured Hot Dogs',
#   'Deluxe Plain Bagels',
#   'Dark Chocolate Sauce',
#   'Lean Smoked Ham'],
#  ['Organic Egg Whites',
#   'Organic Baby Spinach',
#   'Pineapple Chunks',
#   'Organic Half & Half',
#   'Organic Red Onion',
#   'Green Bell Pepper',
#   'Organic Whole Strawberries',
#   'Organic Tomato Paste',
#   'Tomato Sauce',
#   'Jalapeno Peppers',
#   'Organic Whole String Cheese',
#   'Pure Sparkling Water',
#   'Kids Sensible Foods Broccoli Littles',
#   'Peach Pear Flavored Sparkling Water',
#   'Organic Mountain Forest Amber Honey',
#   'Organic Go Go Apple Peach Applesauce',
#   'Vegetarian Organic Chili Beans',
#   'Melatonin 1 Mg Peppermint Sublingual Tablets'],
#  ['Organic Baby Spinach',
#   'Organic Grape Tomatoes',
#   'Electrolyte Enhanced Water',
#   'Hass Avocado',
#   'Vodka Pasta Sauce',
#   'Cookies & Cream Ice Cream',
#   'Organic Spinach And Cheese Ravioli',
#   'Sea Salt Caramel Ice Cream'],
#  ['Lemongrass Citrus Scent Disinfecting Wipes',
#   'Organic Free Range Chicken Broth',
#   'Oyster Crackers',
#   'Honey Bunny Grahams',
#   'Lemongrass & Clementine Zest Natural Dish Liquid',
#   'Saltine Crackers'],
#  ['Banana',
#   'Organic Baby Carrots',
#   'Raspberries',
#   'Organic Blueberries',
#   'Hass Avocados',
#   'Organic Quick Oats',
#   'Classic Green Tea',
#   'Organic Lowfat French Vanilla Yogurt',
#   'Classic Granola',
#   'Molasses Clove Cookies'],
#  ['Organic Hass Avocado',
#   'No Salt Added Black Beans',
#   'Organic Lactose Free 1% Lowfat Milk',
#   'Organic Cucumber',
#   'Apple Honeycrisp Organic',
#   'Frozen Organic Wild Blueberries',
#   'Organic Frozen Peas',
#   'Pomegranate Italian Soda',
#   'Pupusas',
#   ' Pinto Bean & Cheese'],
#  ['Bag of Organic Bananas', 'Mozzarella String Cheese'],
#  ['Organic Ginger Root',
#   'Organic Red Radish',
#   ' Bunch',
#   'Banana',
#   'Honeycrisp Apple',
#   'Large Lemon',
#   'Organic Yellow Onion',
#   'Strawberries',
#   'Unsalted Butter',
#   'Organic Spinach Bunch',
#   'Organic Beefsteak Tomato',
#   'Organic Zucchini',
#   'Sharp Cheddar Cheese',
#   'Organic Baby Broccoli',
#   'Lemon Echinacea Organic Throat Coat Tea',
#   'Half & Half',
#   'Organic Carrot Bunch',
#   'Crushed Red Pepper',
#   'Comice Pear',
#   'Pineapple Strawberry Naturally Essenced Sparkling Water',
#   'Chocolate Hazelnut Non-Dairy Beverage',
#   'Organic Delicata Squash',
#   'Cold & Cough Cough Syrup',
#   'LemonMint Herb Throat Drops'],
#  ['Natural Free & Clear Dishwasher Detergent Packs'],
#  ['Electrolyte Water'],
#  ['Garlic',
#   'Avocado',
#   'Organic Crescent Rolls',
#   'Swaddlers Baby Diapers Jumbo Pack - Size 3',
#   'Size 5 Cruisers Diapers Super Pack',
#   'Kids 2in1 Watermelon Toothpaste & Mouthwash',
#   'Pancake Puffs Banana - 36 PC',
#   'Baby Dry Pampers Baby Dry Diapers Size 5 78 Count Diapers',
#   'Baby Dry Diapers Size 3'],
#  ['Banana',
#   'Chicken & Maple Breakfast Sausage',
#   'Super Spinach! Baby Spinach',
#   ' Baby Bok Choy',
#   ' Sweet Baby Kale',
#   'Quart Sized  Easy Open Freezer Bags',
#   'Tea',
#   ' Organic',
#   ' Egyptian Licorice Mint',
#   ' Caffeine Free',
#   ' Bags',
#   'Organic Stomach Ease Tea Bags'],
#  ['Orange Juice',
#   'Extra Virgin Olive Oil',
#   'Banana',
#   'Honeycrisp Apple',
#   'Large Lemon',
#   'Limes',
#   'Fat Free Milk',
#   'Almond Breeze Original Almond Milk',
#   'Pink Lady (Cripps) Apple',
#   'Non GMO Organic Brown Eggs',
#   'California Orange Juice'],
#  ['Organic Cilantro',
#   'Organic Avocado',
#   'Organic Black Beans',
#   'Organic Tomato Cluster',
#   'Organic Yellow Onion',
#   'Organic Garnet Sweet Potato (Yam)',
#   'Red Peppers',
#   'Fresh Cauliflower',
#   'Unsweetened Vanilla Almond Milk',
#   'Authentic French Brioche Hamburger Buns',
#   'Corn Tortillas',
#   'Old Style Whole Grain Dijon Mustard'],
#  ['Carrots',
#   'Broccoli Florets',
#   'Spaghetti',
#   'Crushed Tomatoes',
#   'Low Fat 1% Milk',
#   'French Bread',
#   'Tomato Paste',
#   'Quick 1 Minute Whole Grain Oats',
#   'Old Fashioned Rolled Oats',
#   'Mighty Mango Juice Smoothie',
#   'Parsnips'],
#  ['Original Hummus'],
#  ['Organic Whole Milk',
#   'Organic Pears',
#   ' Peas and Broccoli Puree Stage 1',
#   'Love Crunch Dark Chocolate And Peanut Butter Granola',
#   'All Natural Classic Guacamole Snack'],
#  ['Creamy Almond Butter',
#   'Salted Tub of Butter',
#   'Chive & Onion Cream Cheese Spread',
#   'Doubleshot Espresso & Cream Premium Coffee Drink'],
#  ['Bag of Organic Bananas',
#   'Green Beans',
#   'Organic Cilantro',
#   'Organic Avocado',
#   "Organic D'Anjou Pears",
#   'Large Lemon',
#   'Organic Gala Apples',
#   'Organic Old Fashioned Rolled Oats',
#   'Large Grapefruit',
#   'Organic Red Potatoes',
#   'Organic Red Cabbage',
#   'Florida Orange Juice With Calcium & Vitamin D',
#   'Chocolate Sorbet',
#   'Tortilla Chips',
#   ' Mexican Kitchen Style',
#   ' Salted',
#   '100% Organic All-Natural Dried Jackfruit'],
#  ['Organic Raspberries',
#   'Organic Baby Carrots',
#   'Organic Grade A Large Brown Eggs',
#   'Light and Lean Quinoa Black Beans with Butternut Squash and Chard',
#   'Brown Rice & Vegetables Bowl',
#   'Organic Quick Oats',
#   'Indian Paneer Tikka',
#   'Total 2% All Natural Low Fat 2% Milkfat Greek Strained Yogurt',
#   'Crunchy Sunflower Seed Bites Sea Salt',
#   'Paneer Tikka Masala With Rajma & Onion Basmati Rice'],
#  ['Sea Salt & Vinegar Potato Chips',
#   'Veganic Sprouted Brown Rice Cacao Crisps',
#   'California Veggie Burger',
#   'Italian Herbs & Olive Oil Mozzarella Stix',
#   'Original Sugar Free Coconut Milk',
#   'Organic Cinnamon Raisin English Muffins'],
#  ['Less Salt Soy Sauce', 'Tomatillo Salsa', 'Reduced Sodium Tamari'],
#  ['Macaroni & Cheese',
#   'Organic Simply Naked Pita Chips',
#   'Shredded Mozzarella Cheese'],
#  ['Bag of Organic Bananas',
#   'Organic Avocado',
#   'White Corn',
#   'Organic Tomato Cluster',
#   'Almond Meal/Flour',
#   'Organic Yellow Onion',
#   'Large Alfresco Eggs',
#   'Organic Garlic',
#   'Creamy Almond Butter',
#   'Ground Turkey Breast',
#   'Chopped Organic Garlic',
#   'Organic Orange Juice',
#   'Applewood Smoked Bacon',
#   'Semolina Flour',
#   'Organic Plain French Style Yogurt',
#   'Pomegranate Blackberry Probiotics Juice Drink',
#   'Pomegranate Blackberry Probiotic Juice Drink',
#   'Ndimaini'],
#  ['Extra Virgin Olive Oil',
#   'Organic Tomato Cluster',
#   'Cucumber Kirby',
#   'Clementines',
#   ' Bag',
#   'Uncured Genoa Salami',
#   'Green Seedless Grapes',
#   'Tomato Ketchup',
#   'Organic Iceberg Lettuce',
#   'Shredded Mild Cheddar Cheese',
#   'Chocolate Ice Cream',
#   'Green Tea With Ginseng and Honey',
#   'Mediterranean Mint Gelato',
#   'Blue Cheese Crumbles',
#   'Organic Finely Shredded Cheddar Cheese',
#   'Sea Salt Caramel Gelato',
#   'Garlic & Fine Herbs Gournay Cheese',
#   'Total 2% All Natural Low Fat 2% Milkfat Greek Strained Yogurt',
#   'Organic Gluten Free Dude Ranch Multigrain Snack Chips'],
#  ['Organic Yellow Onion',
#   'Sea Salt & Vinegar Potato Chips',
#   'Organic Grade A Large Brown Eggs',
#   'Kale Greens',
#   'Peach Pear Flavored Sparkling Water',
#   'Bartlett Pears',
#   'Pink Lady (Cripps) Apple',
#   'Chocolate Chip Cookies',
#   'Ginger Ale Jamaican Style',
#   'Kettle Cooked Jalapeno Potato Chips',
#   '100% Florida Super Red Grapefruit Juice'],
#  ['Baby Spinach',
#   'Strawberries',
#   'Light Multi-Grain English Muffins',
#   'Red Mango',
#   'Super Greens Veggie Burgers',
#   'Active Dry Yeast',
#   'Dijon Mustard Squeeze Bottle',
#   'Celery Hearts',
#   'Unbleached All-Purpose Flour',
#   'Organic Ezekiel 4:9 Sesame Bread',
#   'Organic Baby Spring Mix',
#   'Crunchy Apple Chips Cinnamon'],
#  ['Bag of Organic Bananas',
#   'Watermelon Chunks',
#   'Grated Parmesan Cheese',
#   'Organic Large Grade A Brown Eggs',
#   'Italian Sparkling Mineral Water',
#   'Savory Turkey Breakfast Sausage Patties',
#   'Natural Skincare for Men Body Wash'],
#  ['Carrots',
#   'Organic Baby Spinach',
#   'Extra Virgin Olive Oil',
#   'Banana',
#   'Organic Avocado',
#   'No Salt Added Black Beans',
#   'Large Greenhouse Tomato',
#   'Organic Unsweetened Soy Milk Beverage',
#   'Apple Cider Vinegar',
#   'Fresh Ginger Root',
#   'Organic Peeled Whole Baby Carrots',
#   'Original Hummus',
#   'Garlic',
#   'Organic Basil',
#   'Organic Extra Firm Tofu',
#   'Organic Romaine Lettuce',
#   'Organic Berry Blend',
#   'Ezekiel 4:9 Bread Organic Sprouted Whole Grain',
#   'Organic Chopped Spinach',
#   'Baby Arugula',
#   'Organic Turmeric',
#   'Organic Medjool Dates',
#   'Organic Dijon Mustard',
#   'Taco Seasoning',
#   'Rolled Oats',
#   'Garbanzo Beans No Salt Added',
#   'Organic Soy Tempeh',
#   'Ground Cumin',
#   'Red Cabbage',
#   'Curry Powder',
#   ' Madras',
#   'Sweet Hungarian Paprika'],
#  ['Organic Raspberries',
#   'Organic Hass Avocado',
#   'Green Bell Pepper',
#   'Organic Italian Parsley Bunch',
#   'Natural Premium Coconut Water',
#   'Cucumber & Garlic  Tzatziki',
#   'Orange Calcium & Vitamin D Pulp Free',
#   'Special Reserve Extra Sharp Cheddar Cheese',
#   'Dark Chocolate with Marzipan',
#   'Goat Cheese Log',
#   'Lactose Free Half & Half',
#   "Affi's Aubergine Fire Roasted Eggplant & Garlic All Natural Dip"],
#  ['Frozen Broccoli Florets',
#   'Salted Butter',
#   'Whole Milk',
#   'Reduced Fat Milk 2%',
#   'Organic Cut Green Beans',
#   'Whole Milk Plain Yogurt',
#   'Classic White Bread',
#   'Large Grade AA Cage Free Eggs',
#   'Pineapple Slices',
#   'Alaskan Salmon Burgers'],
#  ['Organic Bread with 21 Whole Grains',
#   'Spring Water',
#   'Organic Unsweetened Almond Milk',
#   'Red Peppers',
#   'Organic Basil',
#   'Organic Spring Mix',
#   'Whipped Cream Cheese',
#   'Dark Coconut Toffee Organic Chocolate',
#   'Himalayan Pink Salt',
#   'Hibiscus Mint Frozen Pops',
#   'Dark Almond Organic Chocolate',
#   'Peppermint Mint Roll'],
#  ['Bag of Organic Bananas',
#   'Clementines',
#   ' Bag',
#   'Organic Cucumber',
#   'Granny Smith Apples',
#   'Original Hummus',
#   'Organic Alfalfa Sprouts',
#   'Organic Red Roasted Peppers'],
#  ['Organic Hass Avocado',
#   'Organic Strawberries',
#   'Total Greek Strained Yogurt',
#   'Organic Lemon',
#   'Organic Extra Large Grade AA Brown Eggs',
#   'Organic White Basmati Rice',
#   'Organic Dill',
#   'Organic Whipping Cream',
#   'Black Forest Ham',
#   'Creme Fraiche French Cultured Cream',
#   'Organic Pecans',
#   'Grated Reggiano Parmigiano'],
#  ['Cereal',
#   'Whole Milk',
#   'Unsweetened Vanilla Almond Milk',
#   'Family Size Naturally Flavored Whole Grain Oats Cereal',
#   'Grape-Nuts Cereal',
#   'Peanut Butter Cereal',
#   'Raisin Bran Crunch Cereal',
#   'Raisin Bran Cereal',
#   'Corn Pops Cereal',
#   'Reduced Fat 2% Milk',
#   'Whole Grain Oat Cereal',
#   'Honey Bunches of Oats Honey Roasted with Almonds Cereal',
#   'Reduced Fat Chocolate Milk',
#   'Frosted Flakes',
#   'Special K Fruit & Yogurt Cereal',
#   'Lucky Charms Cereal',
#   'Special K Vanilla Almond Cereal',
#   'Gluten Free Rice Chex',
#   'Very Vanilla Soymilk'],
#  ['Black Bean Tamale Verde',
#   'Ancient Grain Pasta Gluten-Free Fusilli',
#   'Zero Calorie Cola Soda',
#   'Egg White Chicken Maple Sausage & Cheese Breakfast Sandwich Gluten-Free',
#   'Gluten Free Uncured Pepperoni Pizza'],
#  ['Carrots',
#   'Unsweetened Almondmilk',
#   'Bag of Organic Bananas',
#   'Organic Hass Avocado',
#   'Baby Spinach',
#   'Organic Cilantro',
#   'Organic Whole Milk',
#   'Organic Bosc Pear',
#   'Organic Whole White Mushrooms',
#   'Organic Red Onion',
#   'Organic Red Delicious Apple',
#   'Organic Blueberries',
#   'Organic Gala Apples',
#   'Large Alfresco Eggs',
#   'Liquid Egg Whites',
#   'Organic Romaine',
#   'Unsweetened Original Almond Breeze Almond Milk',
#   'Organic Broccoli',
#   'Organic Red Bell Pepper',
#   'Organic Bell Pepper',
#   'Diet Ginger Ale All Natural Soda',
#   'Organic Hothouse Cucumbers',
#   'Whole Wheat Bread',
#   'Organic Plain Nonfat Greek Yogurt',
#   'Caffeine Free Diet Cola All Natural Soda',
#   'Zero Calorie Cola Soda',
#   'Salsa Fresca',
#   'Sprouted Wheat Cinnamon Raisin Bagels',
#   'Salsa Verde',
#   'Organic Up Beat Coffee Brew',
#   'Morita Salsa'],
#  ['Bag of Organic Bananas',
#   'Organic 2% Reduced Fat Milk',
#   'Tomato Ketchup',
#   'Cinnamon Toast Crunch',
#   'Nutri Grain Bars Multi Pack',
#   'Crunchy Granola Bars Variety Pack'],
#  ['Banana',
#   'Strawberries',
#   'Organic Garlic',
#   'Organic Roasted Turkey Breast',
#   'Limes',
#   'Pita Chips Simply Naked',
#   'Organic Hothouse Cucumbers',
#   'Country Morning White Bread'],
#  ['Banana',
#   'Organic Broccoli Florets',
#   'Red Vine Tomato',
#   'Organic Low Sodium Vegetable Broth',
#   'Organic Sour Cream',
#   'Cucumber Kirby',
#   'Orange Bell Pepper',
#   'Organic Romaine Lettuce',
#   'Corn Tortillas',
#   'Vanilla 0% Milkfat Yogurt',
#   'Taco Seasoning',
#   'Organic Gluten Free Fusilli',
#   'Organic Chopped Garlic',
#   'Soft Taco Size White Flour Tortillas',
#   'Organic Red Lentil Penne',
#   'Cheese',
#   ' Fancy Shredded',
#   ' Mexican Mix',
#   "Qi'a Chia Cranberry Vanilla Buckwheat And Hemp Cereal"],
#  ['Unscented 1000 Sheets Per Roll Bathroom Tissue',
#   'Grade A Organic Large Brown Eggs'],
#  ['Smoothies',
#   ' Strawberries Wild',
#   '100% Pure Apple Juice',
#   'Eggo Pancakes Minis',
#   'Beef Polska Kielbasa',
#   'All Natural Smoothies Razzmatazz'],
#  ['Organic Avocado',
#   'Organic Yellow Onion',
#   'Organic Garnet Sweet Potato (Yam)',
#   'Jalapeno Peppers',
#   'Organic Fresh Carrot Chips',
#   'Organic Red Bell Pepper',
#   'Organic Pumpkin Puree',
#   'Organic Yellow Squash',
#   'The Tonight Dough™ Ice Cream',
#   'Non Dairy Coffee Caramel Fudge',
#   'Milk Free Better Than Sour Cream',
#   'Backyard Barbeque Potato Chips',
#   'Organic Tomato Paste',
#   ' No Salt Added',
#   'Organic Biologique Limes',
#   'Pizza Sauce',
#   'Twelve Essentials Fruit and Vegetable Juice',
#   'Yellow Corn Organic Tortillas',
#   'Krinkle Cut Salt & Fresh Ground Pepper Potato Chips',
#   'Organic Old World Flatbreads Pizza Crust',
#   'Reef Raw Juice'],
#  ['Organic Baby Spinach',
#   'Globe Eggplant',
#   'Organic Large Green Asparagus',
#   'Mild Italian Chicken Sausage',
#   'Organic Broccoli Crowns',
#   'Organic Large Grade AA Omega-3 Eggs',
#   'Sliced Black Olives',
#   'Organic Shredded Carrots',
#   'Plantain Chips',
#   'Sliced Pepperoncini',
#   'Natural Artichoke Hearts Quartered',
#   'Organic Diced Tomatoes with Italian Herbs'],
#  ['Original Orange Juice',
#   'Iceberg Lettuce',
#   'Beef Franks',
#   'Artesano Style Bread',
#   'Original Breakfast Sausage Links',
#   'Eggo Homestyle Waffles',
#   'Organic YoKids Very Berry Smoothies',
#   'Jet-Puffed Marshmallows',
#   'Hardwood Smoked Bacon',
#   'Flip PB&J Low-Fat Greek Yogurt',
#   'Lucky Charms Cereal',
#   'GoGurt Strawberry and Blueberry Tubes',
#   'Original Flavor Macaroni & Cheese Dinner',
#   'Snacks String Cheese Natural Mozzarella Cheese',
#   'Cinnamon Multigrain Cereal',
#   'Cut & Peeled Baby Carrots',
#   'SARA LEE     15OZ PLAIN MINI BAGELS',
#   'Baby Corn on the Cob Whole Spears'],
#  ['Unsweetened Almondmilk',
#   'French Baguettes',
#   ' Take & Bake',
#   ' Twin Pack',
#   'Large Lemon',
#   'Macaroni & Cheese',
#   'Original Veggie Straws',
#   'Spaghetti',
#   'Cheddar Bunnies Snack Crackers',
#   'Organic Edamame',
#   'Hass Avocado',
#   'Baby Food Pears Squash',
#   'Organic Dijon Mustard',
#   'Organic Graham Crunch Cereal',
#   'Peach',
#   '  Apricot & Banana Stage 2 Baby Food',
#   'Organic Letter of the Day Very Vanilla Cookies'],
#  ['Lowfat 2% Milkfat Cottage Cheese',
#   'Sour Cream',
#   'Grape-Nuts Cereal',
#   'Orange Calcium & Vitamin D Pulp Free',
#   'Rotini Pasta',
#   'Old Fashioned Nutty Chunky Peanut Butter'],
#  ['Granny Smith Apples',
#   'Original Hot Sauce',
#   'Vanilla Unsweetened Almond Milk',
#   'India Pale Ale',
#   'Dijon Honey Mustard Dressing',
#   'Hass Avocado',
#   'Strawberry Preserves',
#   'Extra Crisp English Muffins',
#   'Black Tea Pyramids',
#   'Beer',
#   'Spicy Jalapeno Cream Cheese Spread',
#   'Light Imported Beer From Mexico',
#   'Vanilla Soymilk',
#   'Crystallized Ginger & Lemon English Tea Scones'],
#  ['Bag of Organic Bananas',
#   'Vanilla Almond Breeze Almond Milk',
#   'Organic Avocado',
#   'Asparagus',
#   'Red Delicious Apple',
#   'Organic Baby Spinach Salad',
#   'Organic Red Onion',
#   'Large Lemon',
#   'Sinfully Sweet Campari Tomatoes',
#   'Organic Garnet Sweet Potato (Yam)',
#   'Tomato Sauce',
#   'Vegetarian Organic Golden Corn',
#   'Classic Green Tea',
#   'Pure Decaf Green Tea',
#   'Creamy Yogurt 1000 Island Dressing Spread'],
#  ['Organic Baby Spinach',
#   'Bag of Organic Bananas',
#   'Asparagus',
#   'Organic Red Onion',
#   'Feta Cheese Crumbles',
#   'Raspberries',
#   'Organic Grade A Large Brown Eggs',
#   'Shredded Mozzarella',
#   'Radish',
#   'Organic Cripps Pink Apples',
#   'Organic Fresh Squeezed Orange Juice',
#   'Oats & Honey Gluten Free Granola',
#   'Whipped Cream Cheese',
#   'Organic Plain Kefir',
#   'Grilled Chicken Breast Strips',
#   'Tomato Medley',
#   'Triple Creme Goat Brie',
#   'Fajita-Style Grilled Chicken Breast Strips'],
#  ['Honeycrisp Apple',
#   '100% Recycled Paper Towels',
#   'Roasted & Salted Almonds',
#   'Cucumber Kirby',
#   'Organic Blackberries',
#   'Organic Beef Hot Dogs',
#   'Roasted Turkey Breast',
#   'Lemon Yogurt',
#   'Raspberry Yoghurt',
#   'Uncured Hickory Smoked Sunday Bacon',
#   'American Cheese slices',
#   'Farfalle Pasta',
#   'Organic Cinnamon Apple Chips',
#   'Air Chilled Breaded Chicken Breast Nuggets',
#   'Strawberry Rhubarb Yoghurt',
#   'Toasted Sesame Seed Oil',
#   'Edamame In Pod',
#   'Chicken Salad',
#   'Large Premium Wtaerblock Cotton Lined Gloves Pair',
#   'Herbal Popcorn',
#   'Classic Sours Deli Style Pickle Spears'],
#  ['Organic Avocado',
#   'Granny Smith Apples',
#   'Pomelo Grapefruit & Aloe Appeal',
#   'Total 2% All Natural Plain Greek Yogurt',
#   'Kiwi',
#   'Organic Carrots Baby Peeled Prepacked',
#   'Unscented Bathroom Tissue',
#   "Nature's Calorie-Free Sweetener"],
#  ['Milk Chocolate Candy Bars',
#   'Ground Black Pepper',
#   'Coarse Kosher Salt',
#   'Pure Dark Brown Cane Sugar',
#   'Spring Mix',
#   'Boneless Pork Shoulder Butt',
#   'Buttery Homestyle Mashed Potatoes',
#   'Roasted Garlic Mashed Potatoes'],
#  ['Baby Spinach',
#   'Green Beans',
#   'Strawberries',
#   'Blueberries',
#   'Tomato Sauce',
#   'Red Bell Pepper',
#   'Fresh Sugar Snap Peas',
#   'Light & Lean Sweet & Sour Asian Noodle Pasta',
#   'Classic Hummus',
#   'Apple Pie Fruit & Nut Food Bar',
#   'Organic Cauliflower',
#   'Breakfast Raspberry Chia Bars',
#   "Chik'n Nuggets",
#   'Meatles  Soy Gluten-Free Grounds',
#   'Hass Avocado',
#   'Dairy Free Vegetable Pot Pie',
#   'Diced Tomatoes',
#   'Carrot Sticks',
#   'Grapefruit Sparkling Water',
#   'Tomato Paste',
#   'Crunchy Peanut Butter Energy Bar',
#   'Yukon Gold Potatoes',
#   'Organic Green Beans',
#   'Organic Promise Autumn Wheat Cereal',
#   'Carb Balance Small Fajita Whole Wheat Tortillas',
#   'The Big 16 Grain Sprouted Whole Grain Bread',
#   'Sausage  Links',
#   'Potato Puffs with Roasted Garlic and Cracked Black Pepper',
#   'Lemon Zest Nutrition Bars',
#   'Enchilada Black Bean Vegetable',
#   'American Blend Salad',
#   'Cranberry Almond Plus Antioxidants 1.4 oz Fruit & Nut Bars',
#   'Breakfast Honey Oat Gluten Free Non GMO 5 Super Grains Bar Packs',
#   'Activia Peach/Strawberry Lowfat Yogurt',
#   'Organic Sandwich Crackers Peanut Butter',
#   'Activia Mixed Berry/Black Cherry Lowfat Yogurt',
#   'Organic Green Kale',
#   'Diced Potatoes with Onion',
#   'Original Corn Chips',
#   'Five Cheese & Garlic French Bread Pizza Singles',
#   'Kraut',
#   'Granola Bites Honey Almond'],
#  ['Oxy Power Degreaser Ultra Concentrated Dish Liquid',
#   'Peanut Chocolate Candy',
#   'Favorites Alfredo Pasta with Chicken & Broccoli',
#   'Mixed Nuts',
#   'Caramel Praline Crunch Fat Free Frozen Yogurt',
#   'Reduced Fat Creamy Peanut Butter Spread',
#   'Green Plantains',
#   'Meatloaf and Mashed Potatoes',
#   'Frozen Breaded Bagged Chicken Nuggets',
#   'Original 100% Orange Juice with Calcium & Vitamin D',
#   'Whole Grain White Bread',
#   'Vanilla Coke Zero',
#   'Original Cream Cheesecake'],
#  ['gel hand wash sea minerals',
#   'Hazelnut Spread With Skim Milk & Cocoa',
#   'Orange Sparkling Water',
#   'Smartwater Electrolyte Enhanced Water',
#   'Curate Cherry Lime Sparkling Water',
#   'Chicken Fried Rice',
#   'Pure & Natural Light Sour Cream',
#   'Tortilla Chips',
#   ' Mexican Kitchen Style',
#   ' Salted',
#   'Queso Chihuahua Quesadilla Cheese Shredded',
#   'Choose-A-Size White Paper Towels 8 Giant Rolls',
#   'Ultra Comfort Care Mega Roll Toilet Paper',
#   'Craveables Pepperoni Pizza',
#   'Doubleshot Espresso & Cream Premium Coffee Drink',
#   'Reduced Fat Pepperoni Pizza Frozen Sandwiches',
#   'Slow Churned Light Vanilla Bean Ice Cream',
#   'Black Peppercorn Grinder',
#   'Loaded! Potato Skins Cheddar & Bacon'],
#  ['Organic Baby Spinach',
#   'Organic Ginger Root',
#   'Banana',
#   'Organic Cilantro',
#   'Organic Tomato Cluster',
#   'Organic Garlic',
#   'Organic Grade A Large Brown Eggs',
#   'Fresh Cauliflower',
#   'Organic Red Chard Greens',
#   'Organic Italian Parsley Bunch',
#   'Organic Whole Cashews',
#   'Organic Jalapeno Pepper',
#   'Baby Arugula',
#   'Collard Greens',
#   'Pesto Sauce',
#   'Pure Coconut Milk',
#   'Chopped Tomatoes',
#   'Soup',
#   ' Creamy',
#   ' Portobello Mushroom'],
#  ['Bicolor Sweet Corn', 'Genoa Salami', 'Fruit Spread', ' Organic', ' Fig'],
#  ['Carrots',
#   'Bag of Organic Bananas',
#   'Organic Hass Avocado',
#   'Organic Strawberries',
#   'Organic Whole Milk',
#   'Organic Unsalted Butter',
#   'Feta Cheese Crumbles',
#   'Organic Tomato Cluster',
#   'Organic Sunday Bacon',
#   'Pure Sparkling Water',
#   'Grated Parmesan',
#   'Sharp Cheddar Cheese',
#   'Organic Lacinato (Dinosaur) Kale',
#   'Organic Reduced Fat 2% Milk',
#   'Organic Large Brown Grade AA Cage Free Eggs',
#   'Roasted Pumpkin White Cheddar Tamales',
#   'Organic Chicken & Apple Sausage',
#   'Grape White/Green Seedless',
#   'Roasted Salted Cashews',
#   'Organic Medjool Dates',
#   'Stage 1 Apples Sweet Potatoes Pumpkin & Blueberries Organic Pureed Baby Food',
#   'Pink Cripps Apple'],
#  ['Soda',
#   'Original Almondmilk',
#   '0% Greek Strained Yogurt',
#   'Fat Free Skim Milk',
#   'Ginger Ale'],
#  ['Bag of Organic Bananas',
#   'Organic Yams',
#   'Natural Artisan Water',
#   'Chicken Noodle Soup',
#   'Organic Red Potato',
#   'Chicken Breast Cutlets',
#   'Saltine Crackers',
#   'Vanilla Animal Cookies'],
#  ['Curate Cherry Lime Sparkling Water',
#   'Grapefruit Sparkling Water',
#   'Sparkling Natural Spring Water',
#   'Non-Fat Greek Yogurt With Strawberries on the Bottom',
#   'Non-Fat Blueberry on the Bottom Greek Yogurt',
#   'Mighty Mango Juice Smoothie',
#   'Blueberry Crisp Energy Bar',
#   'Strawberry Banana Smoothie',
#   'Gummi Candy',
#   ' Peaches',
#   'English Breakfast Black Tea Bags',
#   "Sour S'ghetti Gummi Candy",
#   'Refreshing Mint Vital Energy Black Tea Blend Bags 16 Count'],
#  ['Prosciutto Di Parma', 'Dry Roasted Macadamias with Sea Salt'],
#  ['Bag of Organic Bananas',
#   'Organic Raspberries',
#   'Organic Baby Carrots',
#   'Clementines',
#   ' Bag',
#   'Organic Lemon',
#   'Organic Bartlett Pear',
#   'XL Emerald White Seedless Grapes',
#   'Colby Cheese Sticks',
#   'Cheerios Cereal'],
#  ['Organic Bunny Fruit Snacks Berry Patch',
#   'Natural Chicken & Sage Breakfast Sausage',
#   'Thin Crust Pepperoni Pizza',
#   'Total 2% Greek Strained Yogurt with Cherry 5.3 oz',
#   'Cherry Preserves',
#   'Maple Honey Ham'],
#  ['Organic Hass Avocado', 'Organic Spring Mix Salad', 'Organic Baby Arugula'],
#  ['Garlic Powder',
#   'Uncured Genoa Salami',
#   'Sea Salt Potato Chips',
#   'Macaroni & Cheese Dinner Original Flavor',
#   'Organic Large Brown Grade AA Cage Free Eggs',
#   'Sweet Potato Yam',
#   'Organic Cherry Tomatoes',
#   'Mozzarella String Cheese',
#   'Broccolini',
#   'Fresh Tilapia Fillet',
#   'Black Pepper Snapea Crisps',
#   'Dried Philippine Mango',
#   'Minis Original Saltine Crackers',
#   'Early Pregnancy Test',
#   'Daily Facial with Sunscreen Moisturizer'],
#  ['Vanilla Bean Ice Cream',
#   'Cane Sugar',
#   'Organic Milk Coffee',
#   'Organic Buckwheat Flour',
#   'Cultured Pasture Butter',
#   'Coarse Sea Salt',
#   'Plain Icelandic Style Skyr 4% milkfat Yogurt',
#   'Pure Madagascar Vanilla Extract',
#   'Baking Bar',
#   ' 70% Bittersweet Chocolate',
#   'Hazelnut Meal/Flour Finely Ground'],
#  ['Unsweetened Almondmilk',
#   'Organic Raspberries',
#   'Banana',
#   'Organic Cilantro',
#   'Yellow Onions',
#   'Brussels Sprouts',
#   'Organic Peeled Whole Baby Carrots',
#   'Small Hass Avocado',
#   'Total 0% Nonfat Greek Yogurt',
#   'Small Macintosh Apple',
#   'Peanut Butter',
#   ' Classic',
#   'Organic Wheat-Free & Gluten-Free Original Crackers',
#   '50% Reduced Fat Sharp Cheddar Cheese'],
#  ['Purified Water',
#   'Gluten Free Peanut Butter Dark Chocolate Chewy With a Crunch Granola Bars',
#   'Popped Dark Chocolate with Sea Salt Granola Bar',
#   'of Hanover 100 Calorie Pretzels Mini',
#   'Dark Chocolate Mocha Granola Bars',
#   'Caramel Macchiato Granola Bars'],
#  ['Natural Shredded Mexican Style Four Cheese',
#   'Uncooked Medium Flour Tortillas',
#   'Burgers Spicy Black Bean Veggie Burgers'],
#  ['Vanilla Almond Breeze',
#   'Ultra Thin Overnight Pads With Flexi-Wings',
#   'Wild Mushroom Ravioli'],
#  ['Organic Strawberries',
#   'Oven Roasted Turkey Breast',
#   'Total 0% with Honey Nonfat Greek Strained Yogurt',
#   'Organic Grade A Free Range Large Brown Eggs',
#   'Organic Fresh Squeezed Orange Juice',
#   'Lavender Floral & Mint Natural Dish Liquid',
#   '2% Reduced Fat DHA Omega-3 Reduced Fat Milk',
#   'Waffles',
#   ' Sweet Belgian',
#   ' Vanilla',
#   'Honey Tangerine Juice'],
#  ['Banana',
#   'Red Vine Tomato',
#   'Gala Apples',
#   'Blueberries',
#   'XL Emerald White Seedless Grapes',
#   'Steamfresh Selects Frozen Broccoli',
#   ' Cauliflower & Carrots',
#   'Bunched Cilantro',
#   'Canned Aranciata Orange',
#   'Chocolate Chip Cookie Dough',
#   'Spinach',
#   'Family Size Naturally Flavored Whole Grain Oats Cereal',
#   '2% Reduced Fat Organic Milk',
#   'Pure Water',
#   'Original Syrup',
#   'Original Whole Grain English Muffins',
#   'Grade AA Large White Eggs',
#   'Double Stuf Oreo Sandwich Cookies',
#   'All Natural Raspberries',
#   'Little Bites Chocolate Chip Muffins',
#   'Dinosaur Shapes Chicken Breast Nuggets',
#   'Acini di Pepe',
#   ' No. 78',
#   'Oreo Mini Bite Size Chocolate Sandwich Cookies',
#   'Original Chocolate Chip Cookies',
#   'G Series Fruit Punch Sports Drink',
#   'Organics Vitamin C Fortified 100% Apple Juice',
#   'Fresh Sliced Mozzarella',
#   'Simply Potaoes Traditional Mashed Potatoes',
#   'Slim Can Cola',
#   'Balanced Breaks White Cheddar with Sea Salted Roasted Almonds and Dried Cranberries',
#   'Fat Free & Lower Sodium Chicken Broth'],
#  ['Organic Strawberries',
#   'Organic Blueberries',
#   'Garlic',
#   'Organic Hothouse Cucumbers',
#   'Organic Iced Oatmeal Cookie ZBar',
#   'Blueberry Muffin Bar',
#   'Organic Arugula'],
#  ['Coconut Milk Nourishing Conditioner', 'Old Fashion Aromatic Bitters'],
#  ['Carrots',
#   'Organic Ginger Root',
#   'Original Orange Juice',
#   'Corn Meal Pizza Crust',
#   'Asparagus',
#   'Cold Brew Coffee',
#   'Organic Tomato Cluster',
#   'Organic Gala Apples',
#   'Organic Spinach Bunch',
#   'Marinara Sauce',
#   'Organic Roasted Turkey Breast',
#   'Organic Beef Uncured Hot Dogs',
#   'Organic Vanilla Almond Milk',
#   'Organic Garbanzo Beans No Salt Added',
#   '100% Recycled Bathroom Tissue',
#   'Organic Extra Large Brown Eggs',
#   'Organic Short Grain Brown Rice',
#   'Peanut Butter Cereal',
#   'Cane Sugar',
#   'Organic Shredded Mozzarella',
#   'Organic Romaine Lettuce',
#   'Almond Milk Blueberry Yogurt',
#   'Organic Apple Juice',
#   'Lavender Hand Soap',
#   '2-Ply Right Size 100% Recycled Paper Towels',
#   'Vanilla Almond Milk Yogurt',
#   'Gluten Free Chia Chia Bread'],
#  ['Organic Ginger Root',
#   'Organic Hass Avocado',
#   'Large Lemon',
#   'Organic Garlic',
#   'Organic Mint',
#   'Organic Small Bunch Celery',
#   'Organic Granny Smith Apple',
#   'Dark Chocolate Frozen Dessert bars',
#   'Two Organic Cornmeal Pizza Crusts'],
#  ['Organic Fuji Apple',
#   'Chicken & Maple Breakfast Sausage',
#   'Dry Rubbed Thick Sliced Pork Bacon',
#   'Semi Soft Part-Skim Cheese',
#   'Brie'],
#  ['Baby Swiss Slices Cheese',
#   'Lemon Italian Sparkling Mineral Water',
#   'Organic Sticks Low Moisture Part Skim Mozzarella String Cheese',
#   'Grape White/Green Seedless',
#   'Tortilla Chips',
#   ' Clasico',
#   ' Jalapeno Lime',
#   'Original No Pulp 100% Florida Orange Juice',
#   'Organic Muenster Cheese Slices',
#   'Organic Sliced Provalone Cheese',
#   'Honey Turkey Breast',
#   'Organic Apple Slices',
#   'Sea Salt & Vinegar Kettle Chips'],
#  ['Energy Drink',
#   '2% Reduced Fat Milk',
#   'Hazelnut Spread With Skim Milk & Cocoa',
#   'Honey Bunches of Oats Honey Roasted Cereal',
#   'Plain Tortilla Strips',
#   'Blueberry Bagels',
#   'Onion Bagels',
#   'Hot Sauce',
#   'Everything Bagel',
#   'Organic Waffles Blueberry',
#   'Hazelnut Creamer',
#   "Mini I.D.'s French Vanilla Creamer",
#   ' Singles',
#   'Buttermilk Pancakes',
#   'Buffalo Style Strips',
#   'Louisana Hot Sauce',
#   'Jumbo Popcorn Chicken'],
#  ['Michigan Organic Kale',
#   'Organic Baby Spinach',
#   'Banana',
#   'Organic Avocado',
#   'Asparagus',
#   'Seedless Red Grapes',
#   'Original Veggie Straws',
#   'Organic Cucumber',
#   'Limes',
#   'Organic Kiwi',
#   'Pure & Natural Sour Cream',
#   'Organic Whole String Cheese',
#   'Fresh Cauliflower',
#   'Organic Butternut Squash',
#   'Natural Classic Pork Breakfast Sausage',
#   'Wild Skipjack Light Tuna',
#   'Broccoli Crown',
#   'Organic Granny Smith Apple',
#   'Yoghurt Blueberry',
#   'Uncured Hickory Smoked Sunday Bacon',
#   'Organic Free Range Grade A Large Brown Eggs',
#   'Waffle Cut Sweet Potato Seasoned Fries',
#   'Organic Yukon Gold Potato Bag',
#   'Original Coconut Milk Creamer',
#   'Honey Almond Butter Single',
#   'Organic Quick Oats',
#   'Ground Black Pepper',
#   'Organic Vanilla Chip Chewy Granola',
#   'Rocky Mountain Sourdough Bread',
#   'Healthy Grains Fiber Cinnamon Oat Clusters',
#   'Organic Unsulphured Molasses'],
#  ['Michigan Organic Kale',
#   'Frozen Broccoli Florets',
#   'Asparagus',
#   'Organic Unsweetened Almond Milk',
#   'Organic Low Sodium Vegetable Broth',
#   'Limes',
#   'Fresh Ginger Root',
#   'Organic Baby Arugula',
#   'Garlic',
#   'Basil',
#   'Extra Thick Whole Grain Rolled Oats',
#   'Onion Powder',
#   'Bunny-Luv Fresh Organic Carrots',
#   'Traditional Hummus',
#   'Herb Crackers',
#   'Organic Black Peppercorns',
#   'Curry Powder',
#   'Garbanzo Beans No Salt Added',
#   'Organic Soy Tempeh',
#   'Ground Cumin'],
#  ['Apricot Preserves',
#   'Dairy-Free Chive Cream Cheese',
#   'Sprouted Multi-Grain Bread',
#   'Supergreens!',
#   "Crispy Chick'n Sliders",
#   'Sparkling Pomegranate',
#   'Vegan Aged White Cheddar Flavor Puffs',
#   'Peanut Toffee Buzz Energy Bar',
#   'Gluten Free Tofu Scramble Breakfast Wrap',
#   'Coconut Milk Non Dairy Frozen Dessert Chocolate Peanut Butter Swirl',
#   'Fresh Veganmozz',
#   'Two Organic Cornmeal Pizza Crusts',
#   'Italian Deli Slices'],
#  ['Organic Hass Avocado',
#   'Sparkling Natural Mineral Water',
#   'Organic Yellow Onion',
#   'Organic Mixed Vegetables',
#   'Organic Gala Apples',
#   'Organic Lemon',
#   'Stage 2 Spinach',
#   ' Apple & Kale',
#   '100% Raw Coconut Water',
#   'Organic Red On the Vine Tomato',
#   'Tortilla Chips',
#   ' Clasico',
#   ' Jalapeno Lime',
#   'YoBaby Blueberry Apple Yogurt',
#   'Organic YoKids Very Berry Smoothies',
#   'Vanilla Bean Chia Pod',
#   'Dark Cacao',
#   'Plain Bagelettes'],
#  ['Organic Unsweetened Almond Milk',
#   '100% Recycled Bathroom Tissue',
#   'Tuna Fillets in Olive Oil',
#   'Organic Pasture Raised Brown Eggs',
#   'Total 2% All Natural Low Fat 2% Milkfat Greek Strained Yogurt'],
#  ['Bag of Organic Bananas',
#   'Organic Raspberries',
#   'Organic Strawberry Fruit Spread',
#   'Organic Red Delicious Apple',
# ...
#   'Organic Baby Bella Mushrooms',
#   'Organic Brussels Sprouts',
#   'Four Potato Hash Browns',
#   'Organic Riced Cauliflower',
#   'Pure Foods Sea Salt Iodized',
#   'Original Creole Seasoning',
#   'Real Cheddar Baked Cheese Puffs',
#   'Raw Coconut Vinegar',
#   'Stringles Organic Colby Jack Cheese',
#   'Chocolate Truffles'],
#  ['Organic Raspberries',
#   'Banana',
#   'Organic Half & Half',
#   'Pure Irish Butter',
#   'Total 0% Greek Yogurt',
#   'Mediterranean Mint Gelato',
#   'Mint Chocolate Chip Protein Bar',
#   'Protein Bar',
#   ' Chocolate Pretzel',
#   'Gluten Free Vegan Chocolate Chocolate Chip Protein Bar',
#   'Organic Apple Butter Spread'],
#  ['Total 2% with Strawberry Lowfat Greek Strained Yogurt',
#   'Seedless Watermelon',
#   'Organic Tomato Basil Pasta Sauce',
#   'Crescent Rolls',
#   'Wild Berry Smoothie',
#   'Organic Turkey Bacon',
#   'Organic YoKids Smoothie Strawberry Banana Lowfat Yogurt',
#   'Kids Sensible Foods Broccoli Littles',
#   'Peach Pear Flavored Sparkling Water',
#   'Organic Sticks Low Moisture Part Skim Mozzarella String Cheese',
#   'Honey Nut Cheerios',
#   'Total 2% Lowfat Greek Strained Yogurt With Blueberry',
#   'Tangerine',
#   'Organic Orange Juice',
#   "S'mores Luna Bar",
#   'Mini Chocolate Chunk Cookies',
#   'Morning Oat Crunch',
#   'Total 2% Greek Strained Yogurt with Cherry 5.3 oz',
#   'Chicken Breast Tenders Breaded',
#   'Farfalle No. 93',
#   'Chocolate Hazelnut Butter Blend',
#   "Organic Honey Nut O's Cereal",
#   'Ripe Large Pitted Olives',
#   'Reduced Fat 2% Chocolate Milk',
#   '93% Ground Beef',
#   'Organic Love Crunch Granola Dark Chocolate & Red Berries',
#   'Garlic Couscous',
#   'Chocolate Delight Granola'],
#  ['Sparkling Water'],
#  ['Organic Avocado',
#   'Organic Fuji Apple',
#   'Pure Irish Butter',
#   'Organic Blackberries',
#   'Organic Pure 85% Dark Chocolate Bar',
#   'Small Hass Avocado',
#   'Organic Red Cabbage',
#   'Organic Whole Cashews',
#   'Organic Spring Mix',
#   'Organic Purple Kale',
#   'Organic Extra Virgin Coconut Oil',
#   'Organic Smooth & Moisturizing Spearmint Peppermint Shaving Gel'],
#  ["Shepherd's Pie",
#   'All Natural Gluten Free Chicken Pot Pie',
#   'Beyond Superfood Blend Natural Cat Food Herring Egg & Sweet Potato'],
#  ['Organic Baby Spinach Salad',
#   'Grassfed Whole Milk Plain Yogurt',
#   'Whole Milk Yogurt'],
#  ['Banana',
#   'Organic Avocado',
#   'Organic Strawberries',
#   'Organic Half & Half',
#   'Organic Grape Tomatoes',
#   'Organic Baby Arugula',
#   'Apple Honeycrisp Organic',
#   'Peanut Butter Creamy With Salt',
#   'Crunchy Peanut Butter',
#   'Sharp Cheddar Cheese',
#   'Shredded Mild Cheddar Cheese',
#   'Cheddar Cheese Nut Thins Cracker Snacks',
#   'Crushed Tomatoes With Basil',
#   'Hearty Minestrone with Vegetables Soup',
#   'Organic Broccoli Crown',
#   'Organic Chocolate 1% Milk with DHA Omega-3',
#   'Organic Lowfat French Vanilla Yogurt',
#   'Organic Rainbow Carrots',
#   'Banana Mango Yogurt',
#   'Whole Wheat Shells & White Cheddar Macaroni and Cheese',
#   'Organic Soups Alphabet Fat Free',
#   'Kidz Baked Chicken Nuggets',
#   "Bernie's Farm Cheddar Crackers",
#   'Organic Fat Free Cottage Cheese',
#   'Whole Wheat Shells & Extra Cheesy Cheddar Sauce Creamy Deluxe Mac & Cheese',
#   'Sandwich Cracker Cheddar',
#   'Organic Healing Balm'],
#  ['Organic Raspberries',
#   'Organic Whole Milk',
#   'Unsalted Butter',
#   'Organic Bartlett Pear'],
#  ['Organic Whole White Mushrooms', 'Organic Sliced Crimini Mushrooms'],
#  ['Cherubs Heavenly Salad Tomatoes',
#   'Whole Vitamin D Milk',
#   'Pitted Greek Kalamata Olives',
#   'Artisan Blends Parmesan Shredded Cheese',
#   'Adult DM Max Cough+Chest Congestion Non-Drowsy Liquid',
#   'NyQuil Cold & Flu Nighttime Relief',
#   'Ibuprofen Drops for ages 6-23 Months',
#   ' White Grape Flavor'],
#  ['Bag of Organic Bananas',
#   'Organic Hass Avocado',
#   'Hair Bender Whole Bean Coffee',
#   'Organic Whole Strawberries',
#   'XL Emerald White Seedless Grapes',
#   'Apple Honeycrisp Organic',
#   'Total 0% Nonfat Plain Greek Yogurt',
#   'Medium Cheddar Cheese Block',
#   'Veggie Bologna Deli Slices',
#   'Organic Cottage Cheese',
#   'Organic Fire Roasted Corn',
#   'Four Cheese Pasta Sauce',
#   'Organic Wheat Square Crackers',
#   'Honey Bunny Grahams',
#   "Teriyaki Chick'n Strips",
#   'Three Cheese Semolina Loaf',
#   'Tofu',
#   ' Soft'],
#  ['Cucumber Kirby',
#   'Red Peppers',
#   'Sour Cream',
#   'Hazelnut Spread With Skim Milk & Cocoa',
#   'Creamy Peanut Butter',
#   'Cage Free Brown Eggs-Large',
#   ' Grade A',
#   'Fridge Pack Cola',
#   'Root Beer',
#   'Red Onions',
#   ' Fresh Diced',
#   'Extra Crunchy Peanut Butter',
#   'Tri-Color Rotini Pasta',
#   'Toll House Semi-Sweet Chocolate Morsels',
#   'Strawberry Squeeze Fruit Spread',
#   'Chocolate Instant Pudding & Pie Filling',
#   'Devils Food Cake Mix',
#   'Restaurant Recipe Italian Dressing'],
#  ['Tiny Twists Pretzels',
#   'French Onion Dip',
#   'Salsa Con Queso Medium',
#   'Original Restaurant Style Party Size Tortilla Chips',
#   'Frontier Whiskey'],
#  ['100% Raw Coconut Water',
#   'Organic Celery Hearts',
#   'Organic Rainbow Carrots',
#   'Organic Almond Non Dairy Beverage Vanilla',
#   'Organic Hemp Pro Fiber Plant Based Protein Supplement'],
#  ['Organic Chicken & Mozzarella Ravioli', 'Prosciutto Di Parma'],
#  ['Bag of Organic Bananas',
#   'Mint Chip',
#   'Vanilla Skyr Nonfat Yogurt',
#   'Island Vanilla Cereal',
#   'Gluten Free Vanilla Granola',
#   'Pretzel Crisps Original Deli Style Pretzel Crackers',
#   'Turmeric',
#   'Organic Dijon Mustard',
#   'Chocolate Chip'],
#  ['Grape Tomatoes',
#   'Bunched Cilantro',
#   'Mini Peeled Carrots',
#   'Celery Sticks',
#   'Grilled Chicken Breast Strips',
#   'Hass Avocado Bag',
#   'Garden Salad Mix',
#   'Seasoned Croutons',
#   'Coke Zero Diet Soda',
#   'Selects Natural Slow Roasted Chicken Breast'],
#  ['Raspberries',
#   'Baby Cucumbers',
#   'Sinfully Sweet Campari Tomatoes',
#   'Strawberries',
#   'Rainbow Bell Peppers',
#   'Kiwi',
#   'Mozzarella Cheese',
#   'Packaged Grape Tomatoes',
#   'Milk Chocolate Almonds',
#   'Heavy Duty Aluminum Foil'],
#  ['Energy Drink',
#   '2% Reduced Fat Milk',
#   'Whole Milk',
#   'Organic Peeled Whole Baby Carrots',
#   'Asparation/Broccolini/Baby Broccoli',
#   'Extra Sharp Cheddar Cheese',
#   'Black Beans',
#   'Rosemary Crackers',
#   'Tri-Color Rotini Pasta',
#   'Tomato and Basil Pasta Sauce',
#   'Crackers',
#   'Snacks String Cheese Natural Mozzarella Cheese',
#   'Spinach Cheese Tortellini',
#   'Black Pearls Medium Pitted Ripe Olives',
#   'Gluten Free Rice Chex',
#   'Small Size Flour Tortillas',
#   'Couscous',
#   ' Israeli',
#   ' Traditional'],
#  ['Organic Baby Spinach',
#   'Organic Red Bell Pepper',
#   'Organic Cripps Pink Apples',
#   'Strawberry Fruit Spread',
#   'Original Burger'],
#  ['Banana',
#   'Organic Black Beans',
#   'Organic Blueberries',
#   'Italian Extra Virgin Olive Oil',
#   'Dark Chocolate Morsels'],
#  ['Vanilla Almond Breeze Almond Milk',
#   'Banana',
#   'Organic Avocado',
#   'Honeycrisp Apple',
#   'Organic Baby Carrots',
#   'Organic Yellow Onion',
#   'Cucumber Kirby',
#   'Beyond Beef Beefy Crumble',
#   'Organic Iceberg Lettuce',
#   'Red Onion',
#   'Organic Creamy Peanut Butter',
#   'Lemongrass & Clementine Zest Natural Dish Liquid',
#   'Protein Power Gluten-Free Black Bean And Quinoa Pasta Elbows',
#   'Black Bean Chipotle Veggie Burger Patties'],
#  ['Organic Ezekiel 49 Bread Cinnamon Raisin',
#   'Organic Red Onion',
#   'Red Grapefruit',
#   'Organic Tomato Cluster',
#   'Raspberries',
#   'Organic Garlic',
#   'Organic Blackberries',
#   'Tomato Sauce',
#   'Organic Green Seedless Grapes',
#   'Limes',
#   'Blackberries',
#   'Red Peppers',
#   'Organic Kiwi',
#   'Icelandic Style Skyr Blueberry Non-fat Yogurt',
#   'Basil',
#   'Organic Lowfat 1% Milk',
#   'Organic Romaine Hearts',
#   'Tomato Kumato',
#   'Sugar Snap Peas',
#   'Mixed Berries Whole Milk Icelandic Style Skyr Yogurt',
#   'Strained Non Fat Orange & Ginger Yogurt',
#   'Almonds & Sea Salt Organic Extra-Dark Chocolate Bar 72% Cocoa',
#   'GOLEAN Crisp! Toasted Berry Crumble Cereal',
#   'Whole Cloves'],
#  ['Watermelon Chunks',
#   'Green Bell Pepper',
#   'Organic English Cucumber',
#   'Organic Yellow Mustard',
#   'Organic Italian Parsley Bunch',
#   '100% Lactose Free Fat Free Milk',
#   'Organic Yellow Squash',
#   'Organic Campari Cocktail Tomatoes',
#   'Lemon Sparkling Mineral Water',
#   'Sliced Portabella Mushrooms'],
#  ['Banana',
#   'Organic Cilantro',
#   'Yellow Onions',
#   'Green Bell Pepper',
#   'Organic Fuji Apple',
#   'Yellow Bell Pepper',
#   'Orange Bell Pepper',
#   'Roma Tomato',
#   'Apple Juice',
#   'Curly Parsley Bunch',
#   'Cranberry Juice Cocktail',
#   'Fresh CA Grown Eggs',
#   'Green Onions',
#   'Honey Greek Yogurt',
#   'Calcium Pulp Free Orange Juice',
#   'Cantaloupe',
#   'Collard Greens',
#   'Raspberry Lemonade',
#   'Hamburger Buns',
#   "Crunchy Oats N' Honey Granola Bars",
#   'Chicken Broth',
#   'Dha Omega 3 Reduced Fat 2% Milk',
#   'Fresh Spinach',
#   'Original Cream Cheese',
#   'Mild Sliced Cheddar Cheese',
#   'Natural Applesauce',
#   'Original Strawberry Gelatin Snacks',
#   'Orzo Pasta',
#   'Thick Cut Bacon',
#   'Cut & Peeled Baby Carrots',
#   'Deluxe Blueberry Bagels',
#   'Ultimate Petite Mixed Vegetables',
#   'Egg Noodles',
#   ' Extra Wide',
#   'Greek Yogurt Style Honey Strawberry',
#   'Cream of Chicken & Mushroom Condensed Soup',
#   'Texas Toast Bread',
#   'Vegetable Stand Combinations Ultimate Southwest Blend',
#   'Cinnamon Raisin Toaster Bagels',
#   'Leafy Romaine',
#   'Solid White Longline Albacore Tuna In Water'],
#  ['Banana',
#   'Globe Eggplant',
#   'Organic Yellow Onion',
#   'Organic Roma Tomato',
#   'Organic Italian Parsley Bunch',
#   'All Natural Marinara Sauce',
#   'Organic Navel Orange',
#   'Sweeet Potato',
#   ' Apple',
#   ' Carrot & Cinnamon Organic Superfoods'],
#  ['Organic Avocado',
#   'Total 2% Lowfat Plain Greek Yogurt',
#   'Red Peppers',
#   'Bunched Cilantro',
#   'Roma Tomato',
#   'Black Beans Reduced Sodium',
#   'Steak Sauce',
#   'Whole Kernel Corn No Salt Added',
#   'Solid White Albacore Tuna In Water',
#   'Ground Cumin',
#   'Rib Eye Steak'],
#  ['Synergy Organic Kombucha Gingerberry',
#   'Organic Mountain Berry Spinach',
#   'Organic Chicken Pot Pie'],
#  ['Organic Strawberries',
#   'Organic Sticks Low Moisture Part Skim Mozzarella String Cheese',
#   'Go Lean Cereal',
#   'Vanilla Almond Breeze',
#   'Apples + Strawberries Organic Nibbly Fingers',
#   'Trop50 No Pulp Orange Juice w/ Calcium + Vitamin D',
#   ' 50% Less Sugar & Calories',
#   'Organic Apple Slices'],
#  ['Sparkling Natural Mineral Water',
#   'Honeycrisp Apple',
#   'Organic Navel Orange',
#   'Squeeze Tomato Ketchup',
#   'Oats & Honey Gluten Free Granola',
#   'Classic Hummus Family Size',
#   'Snacks String Cheese Natural Mozzarella Cheese'],
#  ['Banana',
#   'Large Brown Eggs',
#   'Crispy Seasoned Potato Puffs with Roasted Garlic & Cracked Pepper',
#   'Organic Dark Chocolate Peanut Butter Cups',
#   'ProteinPLUS Multigrain Penne Pasta',
#   'Unsweetened Iced Coffee',
#   'Pretzel Dipping Sticks',
#   'Mango Fruit Nectar'],
#  ['Ataulfo Mango',
#   'XL Emerald White Seedless Grapes',
#   'Organic Kiwi',
#   '100% Raw Coconut Water',
#   'Super Natural Organic Whole Milk'],
#  ['100% Whole Wheat Bread',
#   'Roma Tomato',
#   'Original Whipped Cream Cheese',
#   'Original Cooking Spray',
#   '100% Whole Wheat Pre-Sliced Sandwich Thins',
#   '100% Whole Wheat Medium Soft Taco Flour Tortillas',
#   'Danimals Strawberry Explosion Flavored Smoothie',
#   'Pine Nuts Natural Unsalted'],
#  ['French Baguettes',
#   ' Take & Bake',
#   ' Twin Pack',
#   'Cream Cheese',
#   'Organic Crushed Fire Roasted Tomatoes',
#   'Organic Crushed Tomatoes with Basil',
#   'Organic Diced Tomatoes with Basil & Garlic',
#   'Organic Stewed Tomatoes',
#   'Organic Diced Tomatoes with Italian Herbs',
#   'Blue Cheese Dressing & Dip'],
#  ['Organic Reduced Fat 2% Milk',
#   'Organic Cauliflower',
#   'Breakfast Veggie Bacon Strips',
#   'Garlic',
#   ' Elephant',
#   'Chicken Bouillon Cubes'],
#  ['Bag of Organic Bananas',
#   'Organic Raspberries',
#   'Organic Large Extra Fancy Fuji Apple',
#   'Organic Blackberries',
#   'Organic Reduced Fat 2% Milk',
#   'Gluten Free Pretzel Twists',
#   'Friendo Blendo Espresso Beans'],
#  ['Large Greenhouse Tomato',
#   'Orange Bell Pepper',
#   'Organic Light in Sodium Lentil Vegetable Soup',
#   'Red Onion',
#   'Organic Low Fat Vegetable Barley Soup',
#   'Fresh Whole White Mushrooms',
#   'Organic Bell Pepper',
#   'Organic Medium Chili',
#   'Blueberry Whole Milk Yogurt Pouch',
#   'YoTot Organic Raspberry Pear Yogurt',
#   'Pink Virgin Lemonade',
#   'Yotoddler Organic Pear Spinach Mango Yogurt',
#   'Yo Toddler Organic Strawberry Banana Whole Milk Yogurt'],
#  ['Organic Baby Spinach',
#   'Organic Broccoli Florets',
#   'Organic Yellow Onion',
#   'Organic Large Extra Fancy Fuji Apple',
#   'Organic Quinoa & Brown Rice With Garlic',
#   'Organic Kiwi',
#   'Icelandic Style Skyr Blueberry Non-fat Yogurt',
#   'Organic Whole Wheat Fusilli',
#   'Organic Dill',
#   'Vanilla Skyr Nonfat Yogurt',
#   'Shredded Mozzarella Cheese',
#   'Basil Pesto',
#   'Organic Italian Salad',
#   'Tortilla Chips',
#   ' Clasico',
#   ' Jalapeno Lime',
#   'Pomegranate Arils',
#   'Diet Ginger Ale All Natural Soda',
#   'Free & Clear Unscented Baby Wipes',
#   'Fresh Mozzarella Ball',
#   'Unsweet Peach Water',
#   '2-Ply Right Size 100% Recycled Paper Towels',
#   'Organic Multigrain Tortilla Chips Sub Lime',
#   'Healthy Grains Fiber Cinnamon Oat Clusters',
#   'Grated Parmigiano Reggiano',
#   'Fajita Mix',
#   'Grapefruit Citrus Soda',
#   'Gluten-Free Boom Chicka Pop Salted Caramel popcorn',
#   'Unsweetened Honeydew Essence Water'],
#  ['Organic Baby Spinach',
#   'Organic Cilantro',
#   'Organic Avocado',
#   'Yellow Onions',
#   'Organic Butternut Squash',
#   'Goat Milk',
#   'Organic Yellow Squash',
#   'Authentic Red Curry Paste',
#   'Organic Sweet Potato Puree',
#   'Frozen Blueberries',
#   'Sun Dried Tomatoes',
#   'Bruschetta',
#   ' Artichoke'],
#  ['Pure & Natural Sour Cream',
#   '2-Ply 100% Recycled Bathroom Tissue',
#   'Unsalted Sweet Butter',
#   'David Seeds Sunflower Seeds',
#   'Fresh European Style Baby Arugula',
#   'Frontier Straight 95% Rye Mash Whiskey'],
#  ['Bag of Organic Bananas', 'Raspberries', 'Strawberries', 'Blackberries'],
#  ['Organic Stage 4 Spinach Mango & Pear Baby Food',
#   'Organic Garlic',
#   'Organic Tomato Basil Pasta Sauce',
#   "Chik'n Nuggets",
#   'Sweeet Potato',
#   ' Apple',
#   ' Carrot & Cinnamon Organic Superfoods',
#   'Traditional Plain Greek Yogurt',
#   '100% Whole Wheat Burger Buns',
#   'Peanut Butter Creme Cookies'],
#  ['Organic Strawberries',
#   'Organic Baby Carrots',
#   'Organic Red Onion',
#   'Organic Whole Strawberries',
#   'Roasted & Salted Almonds',
#   'Cucumber Kirby',
#   'Uncured Genoa Salami',
#   'Organic Grape Tomatoes',
#   'Apple Honeycrisp Organic',
#   'Kid Z Bar Organic Honey Graham Energy Snack',
#   'Smoked Turkey Breast Slices',
#   'Atlantic Salmon Fillets',
#   '85% Lean Ground Beef',
#   'Cheddar Bunnies Snack Crackers',
#   'Dried Mango',
#   'Organic Soft Wheat Bread',
#   'Colby Cheese Sticks',
#   'Grape White/Green Seedless',
#   'Original No Pulp 100% Florida Orange Juice',
#   'Spinach Pizza',
#   'Green Tea With Ginseng and Honey',
#   'Organic Spring Mix',
#   'Strawberry Preserves',
#   'Honey Bunny Grahams',
#   'Organic Homestyle Mini Waffles',
#   'Organic Chicken Strips',
#   'Chicken Fried Rice',
#   'Organic Elbows & Creamy Mild Cheddar Sauce Creamy Deluxe Macaroni Dinner',
#   'Dried Cranberries',
#   'Friends Honey',
#   ' Chocolate & Chocolate Chip Bunny Grahams Whole Grain Snacks',
#   "Kid Z Bar Organic S'mores Energy Bars"],
#  ['Strawberries',
#   'Cranberry Juice Cocktail',
#   '100% Whole Wheat Hamburger Buns',
#   'Super Soft Flour Tortillas Fajita Size 20 ct',
#   'Coke de Mexico Glass'],
#  ['Organic Baby Spinach',
#   'Shredded Mozzarella',
#   'Organic Red Bell Pepper',
#   'Organic Whole Crimini Mushrooms',
#   'Cola',
#   'Organic Hot Salsa',
#   'Eggs',
#   ' Cheese & Turkey Sausage Breakfast Burrito',
#   'Mini Babybel Light Semisoft Edam Cheeses',
#   'Whipped Cream Cheese',
#   'Large Brown Grade AA Eggs',
#   'Red Swisschard',
#   'Organic Orange Bell Pepper',
#   'Bean & Rice Chips sea salt',
#   'Ripe Large Pitted Olives',
#   'Juice',
#   ' Raw & Cold-Pressed',
#   ' Purity',
#   'Organic Cultured Low Fat 1% Cottage Cheese',
#   'Plain Bagelettes',
#   'Picnic Potato Salad',
#   'Gluten Free Mild Whole Green Chiles',
#   'Organic Garden Herb Burgers',
#   'Wheat Sandwich Thins',
#   'Concentrated Cold Brew Coffee',
#   'Spinach Florentine Ravioli',
#   'Cream Top Lemon Twist'],
#  ...]

# %% [markdown]
# ###Apriori Algorithm

# %%
te = TransactionEncoder()
te_data = te.fit(data).transform(data)

# Create a dataframe from the data
df_encoded = pd.DataFrame(te_data, columns=te.columns_)
df_encoded
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                 Apricot & Banana Stage 2 Baby Food    Instant   & Baby Wipes  \
# 0      False                                 False      False          False
# 1      False                                 False      False          False
# 2      False                                 False      False          False
# 3      False                                 False      False          False
# 4      False                                 False      False          False
# ...      ...                                   ...        ...            ...
# 32144  False                                 False      False          False
# 32145  False                                 False      False          False
# 32146  False                                 False      False          False
# 32147  False                                 False      False          False
# 32148  False                                 False      False          False
#
#         & Cheese Biscuit   & Cheese Croissant   & Cheese English Muffin  \
# 0                  False                False                     False
# 1                  False                False                     False
# 2                  False                False                     False
# 3                  False                False                     False
# 4                  False                False                     False
# ...                  ...                  ...                       ...
# 32144              False                False                     False
# 32145              False                False                     False
# 32146              False                False                     False
# 32147              False                False                     False
# 32148              False                False                     False
#
#         & Cheese Sandwiches   & Cheese Sauce  \
# 0                     False            False
# 1                     False            False
# 2                     False            False
# 3                     False            False
# 4                     False            False
# ...                     ...              ...
# 32144                 False            False
# 32145                 False            False
# 32146                 False            False
# 32147                 False            False
# 32148                 False            False
#
#         & Coconut With Red Lentils Organic Baby Food  ...  \
# 0                                              False  ...
# 1                                              False  ...
# 2                                              False  ...
# 3                                              False  ...
# 4                                              False  ...
# ...                                              ...  ...
# 32144                                          False  ...
# 32145                                          False  ...
# 32146                                          False  ...
# 32147                                          False  ...
# 32148                                          False  ...
#
#        with Olive Oil Mayonnaise Dressing  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 32144                               False
# 32145                               False
# 32146                               False
# 32147                               False
# 32148                               False
#
#        with Seasoned Roasted Potatoes Scrambled Eggs & Sausage  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 32144                                              False
# 32145                                              False
# 32146                                              False
# 32147                                              False
# 32148                                              False
#
#        with Twist Ties Sandwich & Storage Bags  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 32144                                    False
# 32145                                    False
# 32146                                    False
# 32147                                    False
# 32148                                    False
#
#        with Xylitol Cinnamon 18 Sticks Sugar Free Gum  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# ...                                               ...
# 32144                                           False
# 32145                                           False
# 32146                                           False
# 32147                                           False
# 32148                                           False
#
#        with Xylitol Island Berry Lime 18 Sticks Sugar Free Gum  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 32144                                              False
# 32145                                              False
# 32146                                              False
# 32147                                              False
# 32148                                              False
#
#        with Xylitol Original Flavor 18 Sticks Sugar Free Gum  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 32144                                              False
# 32145                                              False
# 32146                                              False
# 32147                                              False
# 32148                                              False
#
#        with Xylitol Unwrapped Spearmint 50 Sticks Sugar Free Gum  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 32144                                              False
# 32145                                              False
# 32146                                              False
# 32147                                              False
# 32148                                              False
#
#        with Xylitol Watermelon Twist 18 Sticks Sugar Free Gum  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 32144                                              False
# 32145                                              False
# 32146                                              False
# 32147                                              False
# 32148                                              False
#
#        with a Splash of Pineapple Coconut Water  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ...                                         ...
# 32144                                     False
# 32145                                     False
# 32146                                     False
# 32147                                     False
# 32148                                     False
#
#         Lightly Seasoned with Rosemary and Roasted Garlic Family Size Herb Chicken Tortellini
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 32144                                              False
# 32145                                              False
# 32146                                              False
# 32147                                              False
# 32148                                              False
#
# [32149 rows x 26467 columns]

# %%
frequent_itemsets = apriori(df_encoded, min_support=0.01, use_colnames=True)
frequent_itemsets
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       support                                      itemsets
# 0    0.013717                                        ( Bag)
# 1    0.014930                                      ( Bunch)
# 2    0.022178                                    ( Organic)
# 3    0.011042                                 ( Strawberry)
# 4    0.011167                      (100% Raw Coconut Water)
# ..        ...                                           ...
# 118  0.012598                        (Strawberries, Banana)
# 119  0.010420  (Organic Baby Spinach, Organic Hass Avocado)
# 120  0.011384  (Organic Strawberries, Organic Baby Spinach)
# 121  0.013157  (Organic Strawberries, Organic Hass Avocado)
# 122  0.010451   (Organic Strawberries, Organic Raspberries)
#
# [123 rows x 2 columns]

# %% [markdown]
# ###Association Rules

# %%
rules = association_rules(frequent_itemsets, metric="support", min_threshold=0.01)
rules.sort_values(by="support", ascending = False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                  antecedents               consequents  antecedent support  \
# 5   (Bag of Organic Bananas)    (Organic Hass Avocado)            0.121466
# 4     (Organic Hass Avocado)  (Bag of Organic Bananas)            0.067249
# 9   (Bag of Organic Bananas)    (Organic Strawberries)            0.121466
# 8     (Organic Strawberries)  (Bag of Organic Bananas)            0.082615
# 18    (Organic Strawberries)                  (Banana)            0.082615
# 19                  (Banana)    (Organic Strawberries)            0.144732
# 14    (Organic Baby Spinach)                  (Banana)            0.073626
# 15                  (Banana)    (Organic Baby Spinach)            0.144732
# 12                  (Banana)         (Organic Avocado)            0.144732
# 13         (Organic Avocado)                  (Banana)            0.053625
# 3   (Bag of Organic Bananas)    (Organic Baby Spinach)            0.121466
# 2     (Organic Baby Spinach)  (Bag of Organic Bananas)            0.073626
# 27    (Organic Hass Avocado)    (Organic Strawberries)            0.067249
# 26    (Organic Strawberries)    (Organic Hass Avocado)            0.082615
# 6      (Organic Raspberries)  (Bag of Organic Bananas)            0.042427
# 7   (Bag of Organic Bananas)     (Organic Raspberries)            0.121466
# 21                  (Banana)            (Strawberries)            0.144732
# 20            (Strawberries)                  (Banana)            0.045134
# 0              (Clementines)                    ( Bag)            0.021431
# 1                     ( Bag)             (Clementines)            0.013717
# 11                  (Banana)             (Large Lemon)            0.144732
# 10             (Large Lemon)                  (Banana)            0.047560
# 24    (Organic Strawberries)    (Organic Baby Spinach)            0.082615
# 25    (Organic Baby Spinach)    (Organic Strawberries)            0.073626
# 28    (Organic Strawberries)     (Organic Raspberries)            0.082615
# 29     (Organic Raspberries)    (Organic Strawberries)            0.042427
# 17      (Organic Fuji Apple)                  (Banana)            0.028461
# 16                  (Banana)      (Organic Fuji Apple)            0.144732
# 22    (Organic Baby Spinach)    (Organic Hass Avocado)            0.073626
# 23    (Organic Hass Avocado)    (Organic Baby Spinach)            0.067249
#
#     consequent support   support  confidence       lift  leverage  conviction  \
# 5             0.067249  0.019503    0.160563   2.387582  0.011334    1.111163
# 4             0.121466  0.019503    0.290009   2.387582  0.011334    1.237388
# 9             0.082615  0.018134    0.149296   1.807120  0.008099    1.078383
# 8             0.121466  0.018134    0.219503   1.807120  0.008099    1.125609
# 18            0.144732  0.017326    0.209714   1.448977  0.005368    1.082225
# 19            0.082615  0.017326    0.119708   1.448977  0.005368    1.042136
# 14            0.144732  0.015615    0.212083   1.465345  0.004959    1.085479
# 15            0.073626  0.015615    0.107887   1.465345  0.004959    1.038405
# 12            0.053625  0.015490    0.107028   1.995844  0.007729    1.059803
# 13            0.144732  0.015490    0.288863   1.995844  0.007729    1.202677
# 3             0.073626  0.014775    0.121639   1.652121  0.005832    1.054662
# 2             0.121466  0.014775    0.200676   1.652121  0.005832    1.099097
# 27            0.082615  0.013157    0.195652   2.368231  0.007602    1.140532
# 26            0.067249  0.013157    0.159262   2.368231  0.007602    1.109443
# 6             0.121466  0.012940    0.304985   2.510877  0.007786    1.264051
# 7             0.042427  0.012940    0.106530   2.510877  0.007786    1.071746
# 21            0.045134  0.012598    0.087041   1.928511  0.006065    1.045902
# 20            0.144732  0.012598    0.279118   1.928511  0.006065    1.186418
# 0             0.013717  0.012100    0.564586  41.158473  0.011806    2.265162
# 1             0.021431  0.012100    0.882086  41.158473  0.011806    8.299014
# 11            0.047560  0.011913    0.082312   1.730716  0.005030    1.037870
# 10            0.144732  0.011913    0.250491   1.730716  0.005030    1.141103
# 24            0.073626  0.011384    0.137801   1.871640  0.005302    1.074432
# 25            0.082615  0.011384    0.154626   1.871640  0.005302    1.085182
# 28            0.042427  0.010451    0.126506   2.981702  0.006946    1.096255
# 29            0.082615  0.010451    0.246334   2.981702  0.006946    1.217230
# 17            0.144732  0.010420    0.366120   2.529637  0.006301    1.349258
# 16            0.028461  0.010420    0.071997   2.529637  0.006301    1.046913
# 22            0.067249  0.010420    0.141529   2.104546  0.005469    1.086526
# 23            0.073626  0.010420    0.154949   2.104546  0.005469    1.096235
#
#     zhangs_metric
# 5        0.661518
# 4        0.623067
# 9        0.508384
# 8        0.486855
# 18       0.337762
# 19       0.362294
# 14       0.342806
# 15       0.371307
# 12       0.583395
# 13       0.527232
# 3        0.449291
# 2        0.426089
# 27       0.619398
# 26       0.629773
# 6        0.628394
# 7        0.684928
# 21       0.562941
# 20       0.504222
# 0        0.997072
# 1        0.989274
# 11       0.493652
# 10       0.443287
# 24       0.507649
# 25       0.502723
# 28       0.724474
# 29       0.694069
# 17       0.622401
# 16       0.707014
# 22       0.566551
# 23       0.562678
